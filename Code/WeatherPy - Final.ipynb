# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %%
print(cities)
# Out:
# ['adamstown', 'grytviken', 'guarapari', 'ust-nera', 'puri', 'uturoa', 'waitangi', 'bredasdorp', 'wailua homesteads', 'klyuchi', 'aasiaat', 'lebu', 'turpan', 'acapulco de juarez', 'maun', 'hermanus', 'panorama', 'yellowknife', 'arraial do cabo', 'abepura', 'onchan', 'yamada', 'west island', 'saint-francois', 'albany', 'la passe', 'bojnurd', 'norilsk', 'namdrik', 'ancud', 'isafjordur', 'punta arenas', 'taunggyi', 'stephenville', 'talnakh', 'puerto ayora', 'shenjiamen', 'juan de herrera', 'brisas de zicatela', 'thompson', 'severo-yeniseyskiy', 'bethel', 'port-aux-francais', 'stanley', 'posto fiscal rolim de moura', 'whitehorse', 'montereau-fault-yonne', 'baie-comeau', 'sinop', 'toliara', 'sikasso', 'presidente medici', 'hithadhoo', 'tiksi', 'chonchi', 'igede-ekiti', 'maloye ganyushkino', 'koungou', 'guachochi', 'ribeira grande', 'taiohae', 'allendale', 'markovo', 'invercargill', 'bechar', 'malvan', 'sisimiut', 'cidreira', 'buala', 'kavaratti', 'carnarvon', 'mount pearl', 'port pirie', 'karratha', 'blackmans bay', 'bilibino', 'berlin', 'boulder', 'pasni', 'atafu village', 'alotau', 'ilulissat', 'howrah', 'port alfred', 'constantia', 'westport', 'tobi village', 'yangor', 'usakos', 'avarua', 'boguchany', 'yigou', 'fort smith', 'kodiak', 'laguna', 'iskateley', 'sendafa', "likhoslavl'", 'tindouf', 'pisco', "kapa'a", 'palmer', 'tura', 'takamaka', 'longyearbyen', 'zouerate', 'alofi', 'padre bernardo', 'fayroz koh', 'reyes', 'urzhar', 'les cayes', "nar'yan-mar", 'akom ii', 'cascais', 'iqaluit', 'oualidia', 'tazacorte', 'chu', 'luderitz', 'georgetown', 'fort beaufort', 'mount isa', 'ochakiv', 'greenville', 'xiva', 'castanos', 'kirensk', 'mandasa', 'inverurie', 'vila franca do campo', 'puquio', 'ushuaia', 'jinghong', 'port elizabeth', 'harper', 'brownfield', 'campos belos', 'edinburgh of the seven seas', 'port mathurin', 'guerrero negro', 'afaahiti', 'cabo san lucas', 'jamestown', 'la ronge', 'port-vila', 'papatowai', 'akureyri', 'dubbo', 'khanty-mansiysk', 'olonkinbyen', 'saint-joseph', 'yakymivka', 'altamont', 'yuzhno-kurilsk', 'borlange', 'margaret river', 'ammon', 'beshariq', 'keflavik', 'anadyr', 'naze', "arkhangel'sk", 'dalai', 'waingapu', 'revda', 'safotu', 'tazovsky', 'kalix', 'singkil', 'riachao', 'nikolayevsk-on-amure', 'dudinka', 'paris', 'santa cruz', 'horta', 'kapuskasing', 'pucallpa', 'hawaiian paradise park', 'vernon', 'reggane', 'charters towers', 'quelimane', 'senges', 'codrington', 'san patricio', 'moree', 'puerto natales', 'kerikeri', "barka'", 'bubaque', 'nefteyugansk', 'rongelap', 'san antonio de pale', 'graaff-reinet', 'betio village', 'mahibadhoo', 'vetovo', 'petropavlovsk-kamchatsky', 'rio grande', 'oasis', 'port shepstone', 'nanao', 'san luis', 'am djarass', 'robstown', 'vorgashor', 'nishinoomote', 'phan rang-thap cham', 'puerto san jose', 'saint-philippe', 'puerto san carlos', 'noyabrsk', 'matadi', 'haiku-pauwela', 'rawlins', 'asuncion nochixtlan', 'ilhabela', 'bairnsdale', 'qaqortoq', 'pontiac', 'ilebo', 'tual', 'suai', 'enewetak', 'morant bay', 'friedland', 'adam', 'castillos', 'san luis de la loma', 'nova sintra', 'nchelenge', 'korla', 'mazatlan', 'banda aceh', 'gebeit', 'saint-louis', "st. john's", 'recani', 'aginskoye', 'aykhal', 'college', "novhorod-sivers'kyy", 'abuyog', 'suizhou', 'tolanaro', 'timbuktu', 'bridgewater', 'puerto aysen', 'utrik', 'kalmunai', 'fale old settlement', 'chagoda', 'tsiombe', 'azadshahr', 'sinjar', 'nemuro', 'belmonte', 'villamontes', 'kralendijk', 'kalisz', 'cukai', 'sarandi del yi', "'ohonua", 'dieppe', 'sirte', 'manokwari', 'kasungu', 'vizinga', 'manismata', 'kisangani', 'batangafo', 'plouzane', 'aripuana', 'vilyuysk', 'queenstown', 'hamilton', 'jumla', 'sitka', 'brigantine', 'luanda', 'guiberoua', 'katoomba', 'howard springs', 'antsiranana', 'kone', 'odda', 'saipan', 'nogliki', 'lompoc', 'guatrache', 'kourou', 'beidaihehaibin', "la'ie", 'nuuk', 'weno', 'tobelo', 'lardero', 'dolneni', 'vorkuta', 'heihe', 'nadym', 'east london', 'argo', 'xincheng', 'ponta delgada', 'dayr hafir', ' ...

# %%
#sample to understand the data set
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "london"
units = "metric"
city_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(city_url + city).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 8
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.5085,
#         "lon": -0.1257
#     },
#     "dt": 1704693581,
#     "id": 2643743,
#     "main": {
#         "feels_like": 0.31,
#         "humidity": 71,
#         "pressure": 1030,
#         "temp": 2.87,
#         "temp_max": 3.41,
#         "temp_min": 1.86
#     },
#     "name": "London",
#     "sys": {
#         "country": "GB",
#         "id": 2075535,
#         "sunrise": 1704701060,
#         "sunset": 1704730146,
#         "type": 2
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 2.57
#     }
# }

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | guarapari
# Processing Record 4 of Set 1 | ust-nera
# Processing Record 5 of Set 1 | puri
# Processing Record 6 of Set 1 | uturoa
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | wailua homesteads
# Processing Record 10 of Set 1 | klyuchi
# Processing Record 11 of Set 1 | aasiaat
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | turpan
# Processing Record 14 of Set 1 | acapulco de juarez
# Processing Record 15 of Set 1 | maun
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | panorama
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | abepura
# Processing Record 21 of Set 1 | onchan
# Processing Record 22 of Set 1 | yamada
# Processing Record 23 of Set 1 | west island
# Processing Record 24 of Set 1 | saint-francois
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | la passe
# Processing Record 27 of Set 1 | bojnurd
# Processing Record 28 of Set 1 | norilsk
# Processing Record 29 of Set 1 | namdrik
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | isafjordur
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | taunggyi
# Processing Record 34 of Set 1 | stephenville
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | shenjiamen
# Processing Record 38 of Set 1 | juan de herrera
# Processing Record 39 of Set 1 | brisas de zicatela
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | severo-yeniseyskiy
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | port-aux-francais
# Processing Record 44 of Set 1 | stanley
# Processing Record 45 of Set 1 | posto fiscal rolim de moura
# Processing Record 46 of Set 1 | whitehorse
# Processing Record 47 of Set 1 | montereau-fault-yonne
# Processing Record 48 of Set 1 | baie-comeau
# Processing Record 49 of Set 1 | sinop
# Processing Record 50 of Set 1 | toliara
# Processing Record 0 of Set 2 | sikasso
# Processing Record 1 of Set 2 | presidente medici
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | chonchi
# Processing Record 5 of Set 2 | igede-ekiti
# Processing Record 6 of Set 2 | maloye ganyushkino
# Processing Record 7 of Set 2 | koungou
# Processing Record 8 of Set 2 | guachochi
# City not found. Skipping...
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 2 | allendale
# Processing Record 12 of Set 2 | markovo
# Processing Record 13 of Set 2 | invercargill
# Processing Record 14 of Set 2 | bechar
# Processing Record 15 of Set 2 | malvan
# Processing Record 16 of Set 2 | sisimiut
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | buala
# Processing Record 19 of Set 2 | kavaratti
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | mount pearl
# Processing Record 22 of Set 2 | port pirie
# Processing Record 23 of Set 2 | karratha
# Processing Record 24 of Set 2 | blackmans bay
# Processing Record 25 of Set 2 | bilibino
# Processing Record 26 of Set 2 | berlin
# Processing Record 27 of Set 2 | boulder
# Processing Record 28 of Set 2 | pasni
# Processing Record 29 of Set 2 | atafu village
# Processing Record 30 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | howrah
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | constantia
# Processing Record 35 of Set 2 | westport
# Processing Record 36 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 37 of Set 2 | yangor
# City not found. Skipping...
# Processing Record 38 of Set 2 | usakos
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | boguchany
# Processing Record 41 of Set 2 | yigou
# Processing Record 42 of Set 2 | fort smith
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | laguna
# Processing Record 45 of Set 2 | iskateley
# Processing Record 46 of Set 2 | sendafa
# Processing Record 47 of Set 2 | likhoslavl'
# Processing Record 48 of Set 2 | tindouf
# Processing Record 49 of Set 2 | pisco
# Processing Record 0 of Set 3 | kapa'a
# Processing Record 1 of Set 3 | palmer
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | takamaka
# City not found. Skipping...
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | zouerate
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | padre bernardo
# Processing Record 8 of Set 3 | fayroz koh
# Processing Record 9 of Set 3 | reyes
# Processing Record 10 of Set 3 | urzhar
# Processing Record 11 of Set 3 | les cayes
# Processing Record 12 of Set 3 | nar'yan-mar
# Processing Record 13 of Set 3 | akom ii
# Processing Record 14 of Set 3 | cascais
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | oualidia
# City not found. Skipping...
# Processing Record 17 of Set 3 | tazacorte
# Processing Record 18 of Set 3 | chu
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | fort beaufort
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | ochakiv
# Processing Record 24 of Set 3 | greenville
# Processing Record 25 of Set 3 | xiva
# Processing Record 26 of Set 3 | castanos
# Processing Record 27 of Set 3 | kirensk
# Processing Record 28 of Set 3 | mandasa
# Processing Record 29 of Set 3 | inverurie
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | puquio
# Processing Record 32 of Set 3 | ushuaia
# Processing Record 33 of Set 3 | jinghong
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | harper
# Processing Record 36 of Set 3 | brownfield
# Processing Record 37 of Set 3 | campos belos
# Processing Record 38 of Set 3 | edinburgh of the seven seas
# Processing Record 39 of Set 3 | port mathurin
# Processing Record 40 of Set 3 | guerrero negro
# Processing Record 41 of Set 3 | afaahiti
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | la ronge
# Processing Record 45 of Set 3 | port-vila
# Processing Record 46 of Set 3 | papatowai
# Processing Record 47 of Set 3 | akureyri
# Processing Record 48 of Set 3 | dubbo
# Processing Record 49 of Set 3 | khanty-mansiysk
# Processing Record 0 of Set 4 | olonkinbyen
# Processing Record 1 of Set 4 | saint-joseph
# Processing Record 2 of Set 4 | yakymivka
# Processing Record 3 of Set 4 | altamont
# Processing Record 4 of Set 4 | yuzhno-kurilsk
# Processing Record 5 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 6 of Set 4 | margaret river
# Processing Record 7 of Set 4 | ammon
# Processing Record 8 of Set 4 | beshariq
# Processing Record 9 of Set 4 | keflavik
# Processing Record 10 of Set 4 | anadyr
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | arkhangel'sk
# Processing Record 13 of Set 4 | dalai
# Processing Record 14 of Set 4 | waingapu
# Processing Record 15 of Set 4 | revda
# Processing Record 16 of Set 4 | safotu
# Processing Record 17 of Set 4 | tazovsky
# Processing Record 18 of Set 4 | kalix
# Processing Record 19 of Set 4 | singkil
# Processing Record 20 of Set 4 | riachao
# Processing Record 21 of Set 4 | nikolayevsk-on-amure
# Processing Record 22 of Set 4 | dudinka
# Processing Record 23 of Set 4 | paris
# Processing Record 24 of Set 4 | santa cruz
# Processing Record 25 of Set 4 | horta
# Processing Record 26 of Set 4 | kapuskasing
# Processing Record 27 of Set 4 | pucallpa
# Processing Record 28 of Set 4 | hawaiian paradise park
# Processing Record 29 of Set 4 | vernon
# Processing Record 30 of Set 4 | reggane
# Processing Record 31 of Set 4 | charters towers
# Processing Record 32 of Set 4 | quelimane
# Processing Record 33 of Set 4 | senges
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | moree
# Processing Record 37 of Set 4 | puerto natales
# Processing Record 38 of Set 4 | kerikeri
# Processing Record 39 of Set 4 | barka'
# City not found. Skipping...
# Processing Record 40 of Set 4 | bubaque
# Processing Record 41 of Set 4 | nefteyugansk
# Processing Record 42 of Set 4 | rongelap
# Processing Record 43 of Set 4 | san antonio de pale
# Processing Record 44 of Set 4 | graaff-reinet
# Processing Record 45 of Set 4 | betio village
# Processing Record 46 of Set 4 | mahibadhoo
# Processing Record 47 of Set 4 | vetovo
# Processing Record 48 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 49 of Set 4 | rio grande
# Processing Record 0 of Set 5 | oasis
# Processing Record 1 of Set 5 | port shepstone
# Processing Record 2 of Set 5 | nanao
# Processing Record 3 of Set 5 | san luis
# Processing Record 4 of Set 5 | am djarass
# City not found. Skipping...
# Processing Record 5 of Set 5 | robstown
# Processing Record 6 of Set 5 | vorgashor
# Processing Record 7 of Set 5 | nishinoomote
# Processing Record 8 of Set 5 | phan rang-thap cham
# Processing Record 9 of Set 5 | puerto san jose
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 5 | noyabrsk
# Processing Record 13 of Set 5 | matadi
# Processing Record 14 of Set 5 | haiku-pauwela
# Processing Record 15 of Set 5 | rawlins
# Processing Record 16 of Set 5 | asuncion nochixtlan
# Processing Record 17 of Set 5 | ilhabela
# Processing Record 18 of Set 5 | bairnsdale
# Processing Record 19 of Set 5 | qaqortoq
# Processing Record 20 of Set 5 | pontiac
# Processing Record 21 of Set 5 | ilebo
# Processing Record 22 of Set 5 | tual
# Processing Record 23 of Set 5 | suai
# City not found. Skipping...
# Processing Record 24 of Set 5 | enewetak
# Processing Record 25 of Set 5 | morant bay
# Processing Record 26 of Set 5 | friedland
# Processing Record 27 of Set 5 | adam
# Processing Record 28 of Set 5 | castillos
# Processing Record 29 of Set 5 | san luis de la loma
# Processing Record 30 of Set 5 | nova sintra
# Processing Record 31 of Set 5 | nchelenge
# Processing Record 32 of Set 5 | korla
# Processing Record 33 of Set 5 | mazatlan
# Processing Record 34 of Set 5 | banda aceh
# Processing Record 35 of Set 5 | gebeit
# Processing Record 36 of Set 5 | saint-louis
# Processing Record 37 of Set 5 | st. john's
# Processing Record 38 of Set 5 | recani
# Processing Record 39 of Set 5 | aginskoye
# Processing Record 40 of Set 5 | aykhal
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | novhorod-sivers'kyy
# Processing Record 43 of Set 5 | abuyog
# Processing Record 44 of Set 5 | suizhou
# Processing Record 45 of Set 5 | tolanaro
# Processing Record 46 of Set 5 | timbuktu
# Processing Record 47 of Set 5 | bridgewater
# Processing Record 48 of Set 5 | puerto aysen
# Processing Record 49 of Set 5 | utrik
# Processing Record 0 of Set 6 | kalmunai
# Processing Record 1 of Set 6 | fale old settlement
# Processing Record 2 of Set 6 | chagoda
# Processing Record 3 of Set 6 | tsiombe
# Processing Record 4 of Set 6 | azadshahr
# Processing Record 5 of Set 6 | sinjar
# Processing Record 6 of Set 6 | nemuro
# Processing Record 7 of Set 6 | belmonte
# Processing Record 8 of Set 6 | villamontes
# Processing Record 9 of Set 6 | kralendijk
# Processing Record 10 of Set 6 | kalisz
# Processing Record 11 of Set 6 | cukai
# Processing Record 12 of Set 6 | sarandi del yi
# Processing Record 13 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 6 | dieppe
# Processing Record 15 of Set 6 | sirte
# Processing Record 16 of Set 6 | manokwari
# Processing Record 17 of Set 6 | kasungu
# Processing Record 18 of Set 6 | vizinga
# Processing Record 19 of Set 6 | manismata
# Processing Record 20 of Set 6 | kisangani
# Processing Record 21 of Set 6 | batangafo
# Processing Record 22 of Set 6 | plouzane
# Processing Record 23 of Set 6 | aripuana
# Processing Record 24 of Set 6 | vilyuysk
# Processing Record 25 of Set 6 | queenstown
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | jumla
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | brigantine
# Processing Record 30 of Set 6 | luanda
# Processing Record 31 of Set 6 | guiberoua
# Processing Record 32 of Set 6 | katoomba
# Processing Record 33 of Set 6 | howard springs
# Processing Record 34 of Set 6 | antsiranana
# Processing Record 35 of Set 6 | kone
# Processing Record 36 of Set 6 | odda
# Processing Record 37 of Set 6 | saipan
# Processing Record 38 of Set 6 | nogliki
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | guatrache
# Processing Record 41 of Set 6 | kourou
# Processing Record 42 of Set 6 | beidaihehaibin
# Processing Record 43 of Set 6 | la'ie
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | weno
# Processing Record 46 of Set 6 | tobelo
# Processing Record 47 of Set 6 | lardero
# Processing Record 48 of Set 6 | dolneni
# Processing Record 49 of Set 6 | vorkuta
# Processing Record 0 of Set 7 | heihe
# Processing Record 1 of Set 7 | nadym
# Processing Record 2 of Set 7 | east london
# Processing Record 3 of Set 7 | argo
# Processing Record 4 of Set 7 | xincheng
# Processing Record 5 of Set 7 | ponta delgada
# Processing Record 6 of Set 7 | dayr hafir
# Processing Record 7 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 7 | lib
# Processing Record 9 of Set 7 | videira
# Processing Record 10 of Set 7 | crane
# Processing Record 11 of Set 7 | ulaangom
# Processing Record 12 of Set 7 | cape coast
# Processing Record 13 of Set 7 | axim
# Processing Record 14 of Set 7 | san lawrenz
# Processing Record 15 of Set 7 | corning
# Processing Record 16 of Set 7 | sinabang
# Processing Record 17 of Set 7 | chongwe
# Processing Record 18 of Set 7 | wenchang
# Processing Record 19 of Set 7 | laascaanood
# Processing Record 20 of Set 7 | zernograd
# Processing Record 21 of Set 7 | bahia blanca
# Processing Record 22 of Set 7 | halfaya
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | mil'kovo
# Processing Record 25 of Set 7 | coro
# Processing Record 26 of Set 7 | lima
# Processing Record 27 of Set 7 | elmendorf air force base
# City not found. Skipping...
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | darwin
# Processing Record 30 of Set 7 | phalodi
# Processing Record 31 of Set 7 | gualaceo
# Processing Record 32 of Set 7 | black point
# Processing Record 33 of Set 7 | busayra
# Processing Record 34 of Set 7 | muisne
# Processing Record 35 of Set 7 | mata-utu
# Processing Record 36 of Set 7 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | joroinen
# Processing Record 38 of Set 7 | dhidhdhoo
# Processing Record 39 of Set 7 | saham
# Processing Record 40 of Set 7 | pimentel
# Processing Record 41 of Set 7 | kasempa
# Processing Record 42 of Set 7 | lakatoro
# Processing Record 43 of Set 7 | jayapura
# Processing Record 44 of Set 7 | bowen
# Processing Record 45 of Set 7 | holualoa
# Processing Record 46 of Set 7 | nago
# Processing Record 47 of Set 7 | los osos
# Processing Record 48 of Set 7 | badger
# Processing Record 49 of Set 7 | mandalgovi
# Processing Record 0 of Set 8 | yakutsk
# Processing Record 1 of Set 8 | kingston
# Processing Record 2 of Set 8 | fairfax
# Processing Record 3 of Set 8 | cabedelo
# Processing Record 4 of Set 8 | barah
# Processing Record 5 of Set 8 | chegdomyn
# Processing Record 6 of Set 8 | guanica
# Processing Record 7 of Set 8 | beau vallon
# Processing Record 8 of Set 8 | hirado
# Processing Record 9 of Set 8 | tucurui
# Processing Record 10 of Set 8 | ebon
# Processing Record 11 of Set 8 | alice springs
# Processing Record 12 of Set 8 | inderbor
# Processing Record 13 of Set 8 | carutapera
# Processing Record 14 of Set 8 | buon ma thuot
# Processing Record 15 of Set 8 | kamina
# Processing Record 16 of Set 8 | kachug
# Processing Record 17 of Set 8 | tamandare
# Processing Record 18 of Set 8 | prado
# Processing Record 19 of Set 8 | fortuna
# Processing Record 20 of Set 8 | kapit
# Processing Record 21 of Set 8 | el calafate
# Processing Record 22 of Set 8 | kansk
# Processing Record 23 of Set 8 | glace bay
# Processing Record 24 of Set 8 | polyarnyy
# Processing Record 25 of Set 8 | geraldton
# Processing Record 26 of Set 8 | miri
# Processing Record 27 of Set 8 | namibe
# Processing Record 28 of Set 8 | baukau
# Processing Record 29 of Set 8 | tombodu
# Processing Record 30 of Set 8 | coquimbo
# Processing Record 31 of Set 8 | chibougamau
# Processing Record 32 of Set 8 | aral
# Processing Record 33 of Set 8 | amos
# Processing Record 34 of Set 8 | nasir
# Processing Record 35 of Set 8 | katabu
# Processing Record 36 of Set 8 | champerico
# Processing Record 37 of Set 8 | praia da vitoria
# Processing Record 38 of Set 8 | dinguiraye
# Processing Record 39 of Set 8 | ebolowa
# Processing Record 40 of Set 8 | asau
# Processing Record 41 of Set 8 | nova prata
# Processing Record 42 of Set 8 | trincomalee
# Processing Record 43 of Set 8 | ulladulla
# Processing Record 44 of Set 8 | malpica
# Processing Record 45 of Set 8 | luganville
# Processing Record 46 of Set 8 | qapqal
# City not found. Skipping...
# Processing Record 47 of Set 8 | grantsville
# Processing Record 48 of Set 8 | pandan
# Processing Record 49 of Set 8 | boa vista
# Processing Record 0 of Set 9 | machico
# Processing Record 1 of Set 9 | pangoa
# Processing Record 2 of Set 9 | triyuga
# City not found. Skipping...
# Processing Record 3 of Set 9 | sao desiderio
# Processing Record 4 of Set 9 | huarmey
# Processing Record 5 of Set 9 | eilat
# Processing Record 6 of Set 9 | kota kinabalu
# Processing Record 7 of Set 9 | tchibanga
# Processing Record 8 of Set 9 | ode
# Processing Record 9 of Set 9 | barra
# Processing Record 10 of Set 9 | al khums
# Processing Record 11 of Set 9 | navapolatsk
# Processing Record 12 of Set 9 | gamba
# Processing Record 13 of Set 9 | yibin
# Processing Record 14 of Set 9 | macapa
# Processing Record 15 of Set 9 | olyokminsk
# Processing Record 16 of Set 9 | taitung city
# Processing Record 17 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 9 | minas de marcona
# Processing Record 19 of Set 9 | lihue
# Processing Record 20 of Set 9 | hadibu
# Processing Record 21 of Set 9 | basco
# Processing Record 22 of Set 9 | ribas do rio pardo
# Processing Record 23 of Set 9 | patnanungan
# Processing Record 24 of Set 9 | rikaze
# Processing Record 25 of Set 9 | okhotsk
# Processing Record 26 of Set 9 | el bolson
# Processing Record 27 of Set 9 | itoman
# Processing Record 28 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 9 | udachny
# Processing Record 30 of Set 9 | san andres
# Processing Record 31 of Set 9 | nabire
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | richards bay
# Processing Record 34 of Set 9 | kribi
# Processing Record 35 of Set 9 | nyurba
# Processing Record 36 of Set 9 | shingu
# Processing Record 37 of Set 9 | sao raimundo nonato
# Processing Record 38 of Set 9 | puerto baquerizo moreno
# Processing Record 39 of Set 9 | miyaly
# Processing Record 40 of Set 9 | nyagan
# Processing Record 41 of Set 9 | la cabima
# Processing Record 42 of Set 9 | newman
# Processing Record 43 of Set 9 | mingguang
# Processing Record 44 of Set 9 | kamyzyak
# Processing Record 45 of Set 9 | el granada
# Processing Record 46 of Set 9 | puerto lempira
# Processing Record 47 of Set 9 | almazan
# Processing Record 48 of Set 9 | nowrangapur
# City not found. Skipping...
# Processing Record 49 of Set 9 | prainha
# Processing Record 0 of Set 10 | cannonvale
# Processing Record 1 of Set 10 | anar darah
# Processing Record 2 of Set 10 | natal
# Processing Record 3 of Set 10 | kushiro
# Processing Record 4 of Set 10 | labrador city
# Processing Record 5 of Set 10 | kavieng
# Processing Record 6 of Set 10 | ust'-ilimsk
# Processing Record 7 of Set 10 | barcelos
# Processing Record 8 of Set 10 | altamira
# Processing Record 9 of Set 10 | tadmur
# Processing Record 10 of Set 10 | portland
# Processing Record 11 of Set 10 | key west
# Processing Record 12 of Set 10 | lambton shores
# City not found. Skipping...
# Processing Record 13 of Set 10 | larkird
# Processing Record 14 of Set 10 | princeville
# Processing Record 15 of Set 10 | fort bragg
# Processing Record 16 of Set 10 | pariaman
# Processing Record 17 of Set 10 | borjomi
# Processing Record 18 of Set 10 | palopo
# Processing Record 19 of Set 10 | sar-e pul
# Processing Record 20 of Set 10 | komarichi
# Processing Record 21 of Set 10 | yaren
# Processing Record 22 of Set 10 | lautoka
# Processing Record 23 of Set 10 | port isabel
# Processing Record 24 of Set 10 | piacabucu
# Processing Record 25 of Set 10 | ourilandia do norte
# City not found. Skipping...
# Processing Record 26 of Set 10 | thohoyandou
# Processing Record 27 of Set 10 | dwarka
# Processing Record 28 of Set 10 | vilyuchinsk
# Processing Record 29 of Set 10 | jiangyan
# Processing Record 30 of Set 10 | cadale
# Processing Record 31 of Set 10 | totness
# Processing Record 32 of Set 10 | ocean acres
# Processing Record 33 of Set 10 | misratah
# Processing Record 34 of Set 10 | los frentones
# Processing Record 35 of Set 10 | coari
# Processing Record 36 of Set 10 | salekhard
# Processing Record 37 of Set 10 | fort mcmurray
# Processing Record 38 of Set 10 | agustin codazzi
# Processing Record 39 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 10 | lionel town
# Processing Record 41 of Set 10 | berezovo
# Processing Record 42 of Set 10 | al khafji
# Processing Record 43 of Set 10 | gorontalo
# Processing Record 44 of Set 10 | trinidad
# Processing Record 45 of Set 10 | choibalsan
# Processing Record 46 of Set 10 | hojai
# Processing Record 47 of Set 10 | juruti
# Processing Record 48 of Set 10 | kuta
# Processing Record 49 of Set 10 | lodwar
# Processing Record 0 of Set 11 | paraiso
# Processing Record 1 of Set 11 | siwa oasis
# Processing Record 2 of Set 11 | gadzhiyevo
# Processing Record 3 of Set 11 | al kharijah
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | cairns city
# City not found. Skipping...
# Processing Record 6 of Set 11 | ola
# Processing Record 7 of Set 11 | samamea
# City not found. Skipping...
# Processing Record 8 of Set 11 | taroa
# Processing Record 9 of Set 11 | canutama
# Processing Record 10 of Set 11 | andalgala
# Processing Record 11 of Set 11 | petrila
# Processing Record 12 of Set 11 | bornu yassu
# Processing Record 13 of Set 11 | gereida
# Processing Record 14 of Set 11 | quellon
# Processing Record 15 of Set 11 | taoudenni
# Processing Record 16 of Set 11 | morehead city
# Processing Record 17 of Set 11 | zhetybay
# City not found. Skipping...
# Processing Record 18 of Set 11 | vila velha
# Processing Record 19 of Set 11 | lengshuitan
# Processing Record 20 of Set 11 | santiago
# Processing Record 21 of Set 11 | wynyard
# Processing Record 22 of Set 11 | myeik
# Processing Record 23 of Set 11 | guider
# Processing Record 24 of Set 11 | merizo village
# Processing Record 25 of Set 11 | curico
# Processing Record 26 of Set 11 | vilhena
# Processing Record 27 of Set 11 | bandarbeyla
# Processing Record 28 of Set 11 | bol'sherech'ye
# Processing Record 29 of Set 11 | tralee
# Processing Record 30 of Set 11 | alesund
# Processing Record 31 of Set 11 | winejok
# City not found. Skipping...
# Processing Record 32 of Set 11 | kailua-kona
# Processing Record 33 of Set 11 | ontario
# Processing Record 34 of Set 11 | port saint john's
# Processing Record 35 of Set 11 | grand-bourg
# Processing Record 36 of Set 11 | urengoy
# Processing Record 37 of Set 11 | igarka
# Processing Record 38 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 39 of Set 11 | faya-largeau
# Processing Record 40 of Set 11 | yeppoon
# Processing Record 41 of Set 11 | przasnysz
# Processing Record 42 of Set 11 | maragogi
# Processing Record 43 of Set 11 | egilsstadir
# Processing Record 44 of Set 11 | laojunmiao
# Processing Record 45 of Set 11 | rawatbhata
# Processing Record 46 of Set 11 | markivka
# Processing Record 47 of Set 11 | nandigama
# Processing Record 48 of Set 11 | labytnangi
# Processing Record 49 of Set 11 | kasongo-lunda
# Processing Record 0 of Set 12 | lichuan
# Processing Record 1 of Set 12 | nouadhibou
# Processing Record 2 of Set 12 | mildura
# Processing Record 3 of Set 12 | saddle brooke
# City not found. Skipping...
# Processing Record 4 of Set 12 | manado
# Processing Record 5 of Set 12 | socorro
# Processing Record 6 of Set 12 | coahuayana de hidalgo
# Processing Record 7 of Set 12 | lincoln
# Processing Record 8 of Set 12 | corbie
# Processing Record 9 of Set 12 | talara
# Processing Record 10 of Set 12 | kosti
# Processing Record 11 of Set 12 | banjarmasin
# Processing Record 12 of Set 12 | smithers
# Processing Record 13 of Set 12 | konakovo
# Processing Record 14 of Set 12 | sao vicente
# Processing Record 15 of Set 12 | fisterra
# Processing Record 16 of Set 12 | inhambane
# Processing Record 17 of Set 12 | bondo
# Processing Record 18 of Set 12 | sandnessjoen
# Processing Record 19 of Set 12 | alaghsas
# Processing Record 20 of Set 12 | mulayjah
# Processing Record 21 of Set 12 | peniche
# Processing Record 22 of Set 12 | vadso
# Processing Record 23 of Set 12 | abu jibeha
# Processing Record 24 of Set 12 | padang
# Processing Record 25 of Set 12 | ta`u
# Processing Record 26 of Set 12 | kidal
# Processing Record 27 of Set 12 | santiago de cao
# Processing Record 28 of Set 12 | forest grove
# Processing Record 29 of Set 12 | primero de mayo
# Processing Record 30 of Set 12 | kirakira
# Processing Record 31 of Set 12 | abu zabad
# Processing Record 32 of Set 12 | fort st. john
# Processing Record 33 of Set 12 | mexico
# Processing Record 34 of Set 12 | onguday
# Processing Record 35 of Set 12 | sanawad
# Processing Record 36 of Set 12 | caister-on-sea
# Processing Record 37 of Set 12 | colonia
# Processing Record 38 of Set 12 | shizuoka
# Processing Record 39 of Set 12 | bonito
# Processing Record 40 of Set 12 | tudor vladimirescu
# Processing Record 41 of Set 12 | ourem
# Processing Record 42 of Set 12 | burang
# Processing Record 43 of Set 12 | nikol'sk
# Processing Record 44 of Set 12 | elko
# Processing Record 45 of Set 12 | amarpatan
# Processing Record 46 of Set 12 | valley city
# Processing Record 47 of Set 12 | stornoway
# Processing Record 48 of Set 12 | khunti
# Processing Record 49 of Set 12 | xilin hot
# Processing Record 0 of Set 13 | bella union
# Processing Record 1 of Set 13 | posse
# Processing Record 2 of Set 13 | cuatro cienegas de carranza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'adamstown',
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 23.5,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.14,
#   'Country': 'PN',
#   'Date': 1704694236},
#  {'City': 'grytviken',
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': 3.88,
#   'Humidity': 88,
#   'Cloudiness': 50,
#   'Wind Speed': 1.53,
#   'Country': 'GS',
#   'Date': 1704694238},
#  {'City': 'guarapari',
#   'Lat': -20.6667,
#   'Lng': -40.4975,
#   'Max Temp': 24.94,
#   'Humidity': 88,
#   'Cloudiness': 47,
#   'Wind Speed': 2.27,
#   'Country': 'BR',
#   'Date': 1704694239},
#  {'City': 'ust-nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -43.84,
#   'Humidity': 98,
#   'Cloudiness': 81,
#   'Wind Speed': 1.55,
#   'Country': 'RU',
#   'Date': 1704694239},
#  {'City': 'puri',
#   'Lat': 19.8,
#   'Lng': 85.85,
#   'Max Temp': 23.29,
#   'Humidity': 45,
#   'Cloudiness': 13,
#   'Wind Speed': 4.07,
#   'Country': 'IN',
#   'Date': 1704694240},
#  {'City': 'uturoa',
#   'Lat': -16.7333,
#   'Lng': -151.4333,
#   'Max Temp': 27,
#   'Humidity': 79,
#   'Cloudiness': 64,
#   'Wind Speed': 3.7,
#   'Country': 'PF',
#   'Date': 1704694241},
#  {'City': 'waitangi',
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 15.46,
#   'Humidity': 73,
#   'Cloudiness': 10,
#   'Wind Speed': 0.89,
#   'Country': 'NZ',
#   'Date': 1704694241},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 18.27,
#   'Humidity': 66,
#   'Cloudiness': 96,
#   'Wind Speed': 3.46,
#   'Country': 'ZA',
#   'Date': 1704694242},
#  {'City': 'wailua homesteads',
#   'Lat': 22.0669,
#   'Lng': -159.378,
#   'Max Temp': 23.44,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1704694243},
#  {'City': 'klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 1.52,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.72,
#   'Country': 'RU',
#   'Date': 1704694243},
#  {'City': 'aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': -10.64,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.13,
#   'Country': 'GL',
#   'Date': 1704694244},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 12.28,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 3.17,
#   'Country': 'CL',
#   'Date': 1704694245},
#  {'City': 'turpan',
#   'Lat': 42.9333,
#   'Lng': 89.1667,
#   'Max Temp': 2.18,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 0.65,
#   'Country': 'CN',
#   'Date': 1704694246},
#  {'City': 'acapulco de juarez',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 24.9,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'MX',
#   'Date': 1704694246},
#  {'City': 'maun',
#   'Lat': -19.9833,
#   'Lng': 23.4167,
#   'Max Temp': 27.98,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'BW',
#   'Date': 1704694247},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 18.33,
#   'Humidity': 67,
#   'Cloudiness': 30,
#   'Wind Speed': 4.51,
#   'Country': 'ZA',
#   'Date': 1704694248},
#  {'City': 'panorama',
#   'Lat': 40.5878,
#   'Lng': 23.0315,
#   'Max Temp': 9.95,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 5.36,
#   'Country': 'GR',
#   'Date': 1704694248},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -34.84,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': 1704694109},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 23.94,
#   'Humidity': 86,
#   'Cloudiness': 34,
#   'Wind Speed': 7.33,
#   'Country': 'BR',
#   'Date': 1704694250},
#  {'City': 'abepura',
#   'Lat': -2.6333,
#   'Lng': 140.5833,
#   'Max Temp': 31.45,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 0.51,
#   'Country': 'ID',
#   'Date': 1704694250},
#  {'City': 'onchan',
#   'Lat': 54.1733,
#   'Lng': -4.4532,
#   'Max Temp': 4.62,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 7.72,
#   'Country': 'IM',
#   'Date': 1704694251},
#  {'City': 'yamada',
#   'Lat': 39.4667,
#   'Lng': 141.95,
#   'Max Temp': 2.18,
#   'Humidity': 42,
#   'Cloudiness': 10,
#   'Wind Speed': 5.53,
#   'Country': 'JP',
#   'Date': 1704694252},
#  {'City': 'west island',
#   'Lat': -12.1568,
#   'Lng': 96.8225,
#   'Max Temp': 28.99,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'CC',
#   'Date': 1704694252},
#  {'City': 'saint-francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': -0.31,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'FR',
#   'Date': 1704694253},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': -1.29,
#   'Humidity': 82,
#   'Cloudiness': 49,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1704694099},
#  {'City': 'la passe',
#   'Lat': 45.5549,
#   'Lng': -0.8967,
#   'Max Temp': 4.13,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.22,
#   'Country': 'FR',
#   'Date': 1704694254},
#  {'City': 'bojnurd',
#   'Lat': 37.4747,
#   'Lng': 57.329,
#   'Max Temp': 3.97,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'IR',
#   'Date': 1704694255},
#  {'City': 'norilsk',
#   'Lat': 69.3535,
#   'Lng': 88.2027,
#   'Max Temp': -20.88,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.48,
#   'Country': 'RU',
#   'Date': 1704694256},
#  {'City': 'namdrik',
#   'Lat': 5.5994,
#   'Lng': 168.1028,
#   'Max Temp': 28.08,
#   'Humidity': 79,
#   'Cloudiness': 91,
#   'Wind Speed': 9.15,
#   'Country': 'MH',
#   'Date': 1704694256},
#  {'City': 'ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 9.58,
#   'Humidity': 84,
#   'Cloudiness': 8,
#   'Wind Speed': 2.38,
#   'Country': 'CL',
#   'Date': 1704694257},
#  {'City': 'isafjordur',
#   'Lat': 66.0755,
#   'Lng': -23.124,
#   'Max Temp': 4.77,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.22,
#   'Country': 'IS',
#   'Date': 1704694258},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 8.06,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.8,
#   'Country': 'CL',
#   'Date': 1704694258},
#  {'City': 'taunggyi',
#   'Lat': 20.7833,
#   'Lng': 97.0333,
#   'Max Temp': 22.24,
#   'Humidity': 27,
#   'Cloudiness': 4,
#   'Wind Speed': 2.65,
#   'Country': 'MM',
#   'Date': 1704694259},
#  {'City': 'stephenville',
#   'Lat': 32.2207,
#   'Lng': -98.2023,
#   'Max Temp': 11.04,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1704694260},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -21,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.02,
#   'Country': 'RU',
#   'Date': 1704694260},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 24.75,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'EC',
#   'Date': 1704694261},
#  {'City': 'shenjiamen',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp': 10.21,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Country': 'CN',
#   'Date': 1704694262},
#  {'City': 'juan de herrera',
#   'Lat': 18.874,
#   'Lng': -71.2383,
#   'Max Temp': 19.2,
#   'Humidity': 84,
#   'Cloudiness': 4,
#   'Wind Speed': 1.06,
#   'Country': 'DO',
#   'Date': 1704694262},
#  {'City': 'brisas de zicatela',
#   'Lat': 15.8369,
#   'Lng': -97.0419,
#   'Max Temp': 24.76,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 2.1,
#   'Country': 'MX',
#   'Date': 1704694263},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -32.95,
#   'Humidity': 100,
#   'Cloudiness': 16,
#   'Wind Speed': 1.49,
#   'Country': 'CA',
#   'Date': 1704694264},
#  {'City': 'severo-yeniseyskiy',
#   'Lat': 60.3725,
#   'Lng': 93.0408,
#   'Max Temp': -22.46,
#   'Humidity': 97,
#   'Cloudiness': 68,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1704694265},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 1.2,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1704694188},
#  {'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 8.14,
#   'Humidity': 93,
#   'Cloudiness': 73,
#   'Wind Speed': 16.61,
#   'Country': 'TF',
#   'Date': 1704694266},
#  {'City': 'stanley',
#   'Lat': 54.868,
#   'Lng': -1.6985,
#   'Max Temp': 2.65,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 0.51,
#   'Country': 'GB',
#   'Date': 1704694267},
#  {'City': 'posto fiscal rolim de moura',
#   'Lat': -13.0833,
#   'Lng': -62.2667,
#   'Max Temp': 23.34,
#   'Humidity': 92,
#   'Cloudiness': 76,
#   'Wind Speed': 1.22,
#   'Country': 'BR',
#   'Date': 1704694036},
#  {'City': 'whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': -16.06,
#   'Humidity': 75,
#   'Cloudiness': 98,
#   'Wind Speed': 1.79,
#   'Country': 'CA',
#   'Date': 1704694209},
#  {'City': 'montereau-fault-yonne',
#   'Lat': 48.3833,
#   'Lng': 2.95,
#   'Max Temp': -0.29,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'FR',
#   'Date': 1704694269},
#  {'City': 'baie-comeau',
#   'Lat': 49.2168,
#   'Lng': -68.1489,
#   'Max Temp': -11.18,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1704694269},
#  {'City': 'sinop',
#   'Lat': 41.7711,
#   'Lng': 34.8709,
#   'Max Temp': 6.24,
#   'Humidity': 79,
#   'Cloudiness': 97,
#   'Wind Speed': 5.63,
#   'Country': 'TR',
#   'Date': 1704694270},
#  {'City': 'toliara',
#   'Lat': -23.35,
#   'Lng': 43.6667,
#   'Max Temp': 29.39,
#   'Humidity': 66,
#   'Cloudiness': 12,
#   'Wind Speed': 1.75,
#   'Country': 'MG',
#   'Date': 1704694271},
#  {'City': 'sikasso',
#   'Lat': 10.9167,
#   'Lng': -7,
#   'Max Temp': 22.41,
#   'Humidity': 21,
#   'Cloudiness': 51,
#   'Wind Speed': 2.43,
#   'Country': 'ML',
#   'Date': 1704694272},
#  {'City': 'presidente medici',
#   'Lat': -11.1753,
#   'Lng': -61.9014,
#   'Max Temp': 22.79,
#   'Humidity': 94,
#   'Cloudiness': 84,
#   'Wind Speed': 1.41,
#   'Country': 'BR',
#   'Date': 1704694272},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 28.08,
#   'Humidity': 77,
#   'Cloudiness': 69,
#   'Wind Speed': 5.32,
#   'Country': 'MV',
#   'Date': 1704694273},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -33.85,
#   'Humidity': 96,
#   'Cloudiness': 44,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Date': 1704694274},
#  {'City': 'chonchi',
#   'Lat': -42.6128,
#   'Lng': -73.8092,
#   'Max Temp': 7.84,
#   'Humidity': 91,
#   'Cloudiness': 26,
#   'Wind Speed': 0.9,
#   'Country': 'CL',
#   'Date': 1704694274},
#  {'City': 'igede-ekiti',
#   'Lat': 7.6668,
#   'Lng': 5.132,
#   'Max Temp': 19.23,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 0.33,
#   'Country': 'NG',
#   'Date': 1704694275},
#  {'City': 'maloye ganyushkino',
#   'Lat': 46.6,
#   'Lng': 49.2667,
#   'Max Temp': -2.59,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 6.7,
#   'Country': 'KZ',
#   'Date': 1704694276},
#  {'City': 'koungou',
#   'Lat': -12.7336,
#   'Lng': 45.2042,
#   'Max Temp': 28.84,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'YT',
#   'Date': 1704694277},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 15.99,
#   'Humidity': 69,
#   'Cloudiness': 87,
#   'Wind Speed': 4.92,
#   'Country': 'PT',
#   'Date': 1704694278},
#  {'City': 'allendale',
#   'Lat': 42.9723,
#   'Lng': -85.9537,
#   'Max Temp': 2.31,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.12,
#   'Country': 'US',
#   'Date': 1704694280},
#  {'City': 'markovo',
#   'Lat': 57.3206,
#   'Lng': 107.0881,
#   'Max Temp': -18.28,
#   'Humidity': 93,
#   'Cloudiness': 78,
#   'Wind Speed': 1.71,
#   'Country': 'RU',
#   'Date': 1704694281},
#  {'City': 'invercargill',
#   'Lat': -46.4,
#   'Lng': 168.35,
#   'Max Temp': 18.9,
#   'Humidity': 68,
#   'Cloudiness': 80,
#   'Wind Speed': 2.68,
#   'Country': 'NZ',
#   'Date': 1704694282},
#  {'City': 'bechar',
#   'Lat': 31.6167,
#   'Lng': -2.2167,
#   'Max Temp': 7.13,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 1.61,
#   'Country': 'DZ',
#   'Date': 1704694136},
#  {'City': 'malvan',
#   'Lat': 16.0667,
#   'Lng': 73.4667,
#   'Max Temp': 30.93,
#   'Humidity': 41,
#   'Cloudiness': 14,
#   'Wind Speed': 1.71,
#   'Country': 'IN',
#   'Date': 1704694283},
#  {'City': 'sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': -9.56,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.93,
#   'Country': 'GL',
#   'Date': 1704694284},
#  {'City': 'cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 21.95,
#   'Humidity': 92,
#   'Cloudiness': 60,
#   'Wind Speed': 2.57,
#   'Country': 'BR',
#   'Date': 1704694285},
#  {'City': 'buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 27.7,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 1.57,
#   'Country': 'SB',
#   'Date': 1704694285},
#  {'City': 'kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 27.99,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 3.28,
#   'Country': 'IN',
#   'Date': 1704694286},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 26.3,
#   'Humidity': 68,
#   'Cloudiness': 2,
#   'Wind Speed': 7.17,
#   'Country': 'AU',
#   'Date': 1704694287},
#  {'City': 'mount pearl',
#   'Lat': 47.5166,
#   'Lng': -52.7813,
#   'Max Temp': -5.48,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': 1704694287},
#  {'City': 'port pirie',
#   'Lat': -33.1833,
#   'Lng': 138.0167,
#   'Max Temp': 23.29,
#   'Humidity': 58,
#   'Cloudiness': 10,
#   'Wind Speed': 7.31,
#   'Country': 'AU',
#   'Date': 1704694288},
#  {'City': 'karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 40.12,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 7.37,
#   'Country': 'AU',
#   'Date': 1704694289},
#  {'City': 'blackmans bay',
#   'Lat': -43.0167,
#   'Lng': 147.3167,
#   'Max Temp': 16.52,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'AU',
#   'Date': 1704694290},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -29.45,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.08,
#   'Country': 'RU',
#   'Date': 1704694290},
#  {'City': 'berlin',
#   'Lat': 52.5244,
#   'Lng': 13.4105,
#   'Max Temp': -6.49,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Country': 'DE',
#   'Date': 1704693608},
#  {'City': 'boulder',
#   'Lat': 40.0833,
#   'Lng': -105.3505,
#   'Max Temp': -5.27,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': 1704694292},
#  {'City': 'pasni',
#   'Lat': 25.2631,
#   'Lng': 63.471,
#   'Max Temp': 22.96,
#   'Humidity': 33,
#   'Cloudiness': 3,
#   'Wind Speed': 9.64,
#   'Country': 'PK',
#   'Date': 1704694293},
#  {'City': 'atafu village',
#   'Lat': -8.5421,
#   'Lng': -172.5159,
#   'Max Temp': 28.7,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 1.51,
#   'Country': 'TK',
#   'Date': 1704694294},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': -7.99,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Country': 'GL',
#   'Date': 1704694295},
#  {'City': 'howrah',
#   'Lat': 22.5892,
#   'Lng': 88.3103,
#   'Max Temp': 21,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 3.09,
#   'Country': 'IN',
#   'Date': 1704694296},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 18.43,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'ZA',
#   'Date': 1704694297},
#  {'City': 'constantia',
#   'Lat': 44.1833,
#   'Lng': 28.65,
#   'Max Temp': 0.39,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 8.55,
#   'Country': 'RO',
#   'Date': 1704694297},
#  {'City': 'westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 2.27,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1704694298},
#  {'City': 'usakos',
#   'Lat': -22,
#   'Lng': 15.6,
#   'Max Temp': 24.67,
#   'Humidity': 28,
#   'Cloudiness': 73,
#   'Wind Speed': 2.35,
#   'Country': 'NA',
#   'Date': 1704694300},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 26.03,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'CK',
#   'Date': 1704694167},
#  {'City': 'boguchany',
#   'Lat': 58.3814,
#   'Lng': 97.4531,
#   'Max Temp': -18.97,
#   'Humidity': 96,
#   'Cloudiness': 95,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': 1704694301},
#  {'City': 'yigou',
#   'Lat': 35.8114,
#   'Lng': 114.3167,
#   'Max Temp': 7.32,
#   'Humidity': 38,
#   'Cloudiness': 35,
#   'Wind Speed': 5.51,
#   'Country': 'CN',
#   'Date': 1704694302},
#  {'City': 'fort smith',
#   'Lat': 35.3859,
#   'Lng': -94.3986,
#   'Max Temp': 6.18,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1704694204},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 0.73,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1704694303},
#  {'City': 'laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 7.28,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1704694304},
#  {'City': 'iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': -11.96,
#   'Humidity': 95,
#   'Cloudiness': 85,
#   'Wind Speed': 2.23,
#   'Country': 'RU',
#   'Date': 1704694305},
#  {'City': 'sendafa',
#   'Lat': 9.15,
#   'Lng': 39.0333,
#   'Max Temp': 13.76,
#   'Humidity': 60,
#   'Cloudiness': 26,
#   'Wind Speed': 2.09,
#   'Country': 'ET',
#   'Date': 1704694305},
#  {'City': "likhoslavl'",
#   'Lat': 57.1275,
#   'Lng': 35.464,
#   'Max Temp': -20.64,
#   'Humidity': 90,
#   'Cloudiness': 32,
#   'Wind Speed': 2.49,
#   'Country': 'RU',
#   'Date': 1704694306},
#  {'City': 'tindouf',
#   'Lat': 27.6711,
#   'Lng': -8.1474,
#   'Max Temp': 8.25,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'DZ',
#   'Date': 1704694307},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 21.03,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'PE',
#   'Date': 1704694308},
#  {'City': "kapa'a",
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 24.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1704694308},
#  {'City': 'palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': -1.99,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694152},
#  {'City': 'tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 22.9,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 2.53,
#   'Country': 'IN',
#   'Date': 1704694310},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': -14.09,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'SJ',
#   'Date': 1704694311},
#  {'City': 'zouerate',
#   'Lat': 22.7187,
#   'Lng': -12.4521,
#   'Max Temp': 16.11,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 3.11,
#   'Country': 'MR',
#   'Date': 1704694312},
#  {'City': 'alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 27.18,
#   'Humidity': 81,
#   'Cloudiness': 48,
#   'Wind Speed': 3.38,
#   'Country': 'NU',
#   'Date': 1704694312},
#  {'City': 'padre bernardo',
#   'Lat': -15.35,
#   'Lng': -48.5,
#   'Max Temp': 20.73,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.28,
#   'Country': 'BR',
#   'Date': 1704694036},
#  {'City': 'fayroz koh',
#   'Lat': 34.5195,
#   'Lng': 65.2509,
#   'Max Temp': -2.06,
#   'Humidity': 81,
#   'Cloudiness': 52,
#   'Wind Speed': 1.49,
#   'Country': 'AF',
#   'Date': 1704694314},
#  {'City': 'reyes',
#   'Lat': -14.3167,
#   'Lng': -67.3833,
#   'Max Temp': 23.53,
#   'Humidity': 96,
#   'Cloudiness': 50,
#   'Wind Speed': 0.83,
#   'Country': 'BO',
#   'Date': 1704694314},
#  {'City': 'urzhar',
#   'Lat': 47.093,
#   'Lng': 81.6294,
#   'Max Temp': -1.38,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.11,
#   'Country': 'KZ',
#   'Date': 1704694315},
#  {'City': 'les cayes',
#   'Lat': 18.2,
#   'Lng': -73.75,
#   'Max Temp': 23.67,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 1.91,
#   'Country': 'HT',
#   'Date': 1704694316},
#  {'City': "nar'yan-mar",
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': -11.71,
#   'Humidity': 95,
#   'Cloudiness': 85,
#   'Wind Speed': 2.28,
#   'Country': 'RU',
#   'Date': 1704694316},
#  {'City': 'akom ii',
#   'Lat': 2.7833,
#   'Lng': 10.5667,
#   'Max Temp': 22.98,
#   'Humidity': 87,
#   'Cloudiness': 88,
#   'Wind Speed': 0.05,
#   'Country': 'CM',
#   'Date': 1704694317},
#  {'City': 'cascais',
#   'Lat': 38.6979,
#   'Lng': -9.4215,
#   'Max Temp': 9.73,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 3.13,
#   'Country': 'PT',
#   'Date': 1704694318},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -19.15,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CA',
#   'Date': 1704694318},
#  {'City': 'tazacorte',
#   'Lat': 28.629,
#   'Lng': -17.9293,
#   'Max Temp': 17.86,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'ES',
#   'Date': 1704694320},
#  {'City': 'chu',
#   'Lat': 43.5983,
#   'Lng': 73.7614,
#   'Max Temp': 5.77,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.51,
#   'Country': 'KZ',
#   'Date': 1704694320},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 18.32,
#   'Humidity': 71,
#   'Cloudiness': 55,
#   'Wind Speed': 10.67,
#   'Country': 'NA',
#   'Date': 1704694321},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 32.96,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': 1704694139},
#  {'City': 'fort beaufort',
#   'Lat': -32.7748,
#   'Lng': 26.6338,
#   'Max Temp': 17.66,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 0.75,
#   'Country': 'ZA',
#   'Date': 1704694322},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 31.87,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'AU',
#   'Date': 1704694323},
#  {'City': 'ochakiv',
#   'Lat': 46.6128,
#   'Lng': 31.5498,
#   'Max Temp': 3.76,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.46,
#   'Country': 'UA',
#   'Date': 1704694324},
#  {'City': 'greenville',
#   'Lat': 35.6127,
#   'Lng': -77.3663,
#   'Max Temp': 6.18,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694108},
#  {'City': 'xiva',
#   'Lat': 41.3783,
#   'Lng': 60.3639,
#   'Max Temp': 2.99,
#   'Humidity': 57,
#   'Cloudiness': 21,
#   'Wind Speed': 6.02,
#   'Country': 'UZ',
#   'Date': 1704694325},
#  {'City': 'castanos',
#   'Lat': 26.7833,
#   'Lng': -101.4167,
#   'Max Temp': 12.41,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.3,
#   'Country': 'MX',
#   'Date': 1704694326},
#  {'City': 'kirensk',
#   'Lat': 57.7853,
#   'Lng': 108.1119,
#   'Max Temp': -20.58,
#   'Humidity': 96,
#   'Cloudiness': 84,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1704694327},
#  {'City': 'mandasa',
#   'Lat': 18.8667,
#   'Lng': 84.4667,
#   'Max Temp': 28.27,
#   'Humidity': 37,
#   'Cloudiness': 47,
#   'Wind Speed': 4.76,
#   'Country': 'IN',
#   'Date': 1704694328},
#  {'City': 'inverurie',
#   'Lat': 57.2845,
#   'Lng': -2.3774,
#   'Max Temp': 0.36,
#   'Humidity': 100,
#   'Cloudiness': 12,
#   'Wind Speed': 1.03,
#   'Country': 'GB',
#   'Date': 1704694328},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 14.23,
#   'Humidity': 88,
#   'Cloudiness': 47,
#   'Wind Speed': 2.77,
#   'Country': 'PT',
#   'Date': 1704694329},
#  {'City': 'puquio',
#   'Lat': -14.7,
#   'Lng': -74.1333,
#   'Max Temp': 13.67,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 1.42,
#   'Country': 'PE',
#   'Date': 1704694330},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 2.7,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 2.98,
#   'Country': 'AR',
#   'Date': 1704694331},
#  {'City': 'jinghong',
#   'Lat': 21.991,
#   'Lng': 100.7341,
#   'Max Temp': 27.7,
#   'Humidity': 29,
#   'Cloudiness': 7,
#   'Wind Speed': 1.3,
#   'Country': 'CN',
#   'Date': 1704694331},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 18.39,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'ZA',
#   'Date': 1704694332},
#  {'City': 'harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 26.67,
#   'Humidity': 85,
#   'Cloudiness': 13,
#   'Wind Speed': 2.69,
#   'Country': 'LR',
#   'Date': 1704694333},
#  {'City': 'brownfield',
#   'Lat': 33.1812,
#   'Lng': -102.2744,
#   'Max Temp': 9.97,
#   'Humidity': 78,
#   'Cloudiness': 84,
#   'Wind Speed': 11.56,
#   'Country': 'US',
#   'Date': 1704694333},
#  {'City': 'campos belos',
#   'Lat': -13.0367,
#   'Lng': -46.7717,
#   'Max Temp': 21.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.96,
#   'Country': 'BR',
#   'Date': 1704694085},
#  {'City': 'edinburgh of the seven seas',
#   'Lat': -37.0676,
#   'Lng': -12.3116,
#   'Max Temp': 16.99,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.45,
#   'Country': 'SH',
#   'Date': 1704694335},
#  {'City': 'port mathurin',
#   'Lat': -19.6833,
#   'Lng': 63.4167,
#   'Max Temp': 27.63,
#   'Humidity': 69,
#   'Cloudiness': 43,
#   'Wind Speed': 2.97,
#   'Country': 'MU',
#   'Date': 1704694336},
#  {'City': 'guerrero negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 14.56,
#   'Humidity': 48,
#   'Cloudiness': 38,
#   'Wind Speed': 8.1,
#   'Country': 'MX',
#   'Date': 1704694337},
#  {'City': 'afaahiti',
#   'Lat': -17.75,
#   'Lng': -149.2833,
#   'Max Temp': 24.93,
#   'Humidity': 85,
#   'Cloudiness': 53,
#   'Wind Speed': 5.48,
#   'Country': 'PF',
#   'Date': 1704694338},
#  {'City': 'cabo san lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 19.31,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 0.45,
#   'Country': 'MX',
#   'Date': 1704694161},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 1.42,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1704694075},
#  {'City': 'la ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': -30.86,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': 1704694340},
#  {'City': 'port-vila',
#   'Lat': -17.7338,
#   'Lng': 168.3219,
#   'Max Temp': 28.78,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'VU',
#   'Date': 1704694341},
#  {'City': 'papatowai',
#   'Lat': -46.5619,
#   'Lng': 169.4708,
#   'Max Temp': 16.62,
#   'Humidity': 65,
#   'Cloudiness': 97,
#   'Wind Speed': 2.28,
#   'Country': 'NZ',
#   'Date': 1704694342},
#  {'City': 'akureyri',
#   'Lat': 65.6835,
#   'Lng': -18.0878,
#   'Max Temp': 7.96,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'IS',
#   'Date': 1704694342},
#  {'City': 'dubbo',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 20.07,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'AU',
#   'Date': 1704694343},
#  {'City': 'khanty-mansiysk',
#   'Lat': 61.0042,
#   'Lng': 69.0019,
#   'Max Temp': -21.94,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 2,
#   'Country': 'RU',
#   'Date': 1704694344},
#  {'City': 'olonkinbyen',
#   'Lat': 70.9221,
#   'Lng': -8.7187,
#   'Max Temp': 1.94,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.94,
#   'Country': 'SJ',
#   'Date': 1704694345},
#  {'City': 'saint-joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 28.21,
#   'Humidity': 73,
#   'Cloudiness': 43,
#   'Wind Speed': 4.2,
#   'Country': 'RE',
#   'Date': 1704694345},
#  {'City': 'yakymivka',
#   'Lat': 46.6897,
#   'Lng': 35.1536,
#   'Max Temp': 1.15,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.1,
#   'Country': 'UA',
#   'Date': 1704694346},
#  {'City': 'altamont',
#   'Lat': 42.2068,
#   'Lng': -121.7372,
#   'Max Temp': -3.67,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694347},
#  {'City': 'yuzhno-kurilsk',
#   'Lat': 44.0306,
#   'Lng': 145.8556,
#   'Max Temp': -1.46,
#   'Humidity': 79,
#   'Cloudiness': 60,
#   'Wind Speed': 7.76,
#   'Country': 'RU',
#   'Date': 1704694348},
#  {'City': 'margaret river',
#   'Lat': -33.95,
#   'Lng': 115.0667,
#   'Max Temp': 23.63,
#   'Humidity': 62,
#   'Cloudiness': 96,
#   'Wind Speed': 7.36,
#   'Country': 'AU',
#   'Date': 1704694349},
#  {'City': 'ammon',
#   'Lat': 43.4696,
#   'Lng': -111.9666,
#   'Max Temp': -10.66,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694350},
#  {'City': 'beshariq',
#   'Lat': 40.4358,
#   'Lng': 70.6103,
#   'Max Temp': 8.67,
#   'Humidity': 59,
#   'Cloudiness': 97,
#   'Wind Speed': 0.97,
#   'Country': 'UZ',
#   'Date': 1704694351},
#  {'City': 'keflavik',
#   'Lat': 64.0049,
#   'Lng': -22.5624,
#   'Max Temp': 8.95,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Country': 'IS',
#   'Date': 1704694351},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -14.72,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'RU',
#   'Date': 1704694352},
#  {'City': 'naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 13.53,
#   'Humidity': 60,
#   'Cloudiness': 87,
#   'Wind Speed': 2.48,
#   'Country': 'JP',
#   'Date': 1704694353},
#  {'City': "arkhangel'sk",
#   'Lat': 64.5401,
#   'Lng': 40.5433,
#   'Max Temp': -11.04,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'RU',
#   'Date': 1704694354},
#  {'City': 'dalai',
#   'Lat': 45.5,
#   'Lng': 124.3,
#   'Max Temp': -10.99,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 4.06,
#   'Country': 'CN',
#   'Date': 1704694354},
#  {'City': 'waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 30.35,
#   'Humidity': 70,
#   'Cloudiness': 91,
#   'Wind Speed': 3.89,
#   'Country': 'ID',
#   'Date': 1704694355},
#  {'City': 'revda',
#   'Lat': 56.801,
#   'Lng': 59.9303,
#   'Max Temp': -24.52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'RU',
#   'Date': 1704694356},
#  {'City': 'safotu',
#   'Lat': -13.4513,
#   'Lng': -172.4018,
#   'Max Temp': 28.88,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 2.38,
#   'Country': 'WS',
#   'Date': 1704694356},
#  {'City': 'tazovsky',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -22.26,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 4.1,
#   'Country': 'RU',
#   'Date': 1704694357},
#  {'City': 'kalix',
#   'Lat': 65.853,
#   'Lng': 23.1565,
#   'Max Temp': -6.34,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 2.93,
#   'Country': 'SE',
#   'Date': 1704694358},
#  {'City': 'singkil',
#   'Lat': -7.9855,
#   'Lng': 111.4161,
#   'Max Temp': 27.46,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 0.31,
#   'Country': 'ID',
#   'Date': 1704694358},
#  {'City': 'riachao',
#   'Lat': -7.3619,
#   'Lng': -46.6172,
#   'Max Temp': 22.33,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.63,
#   'Country': 'BR',
#   'Date': 1704694359},
#  {'City': 'nikolayevsk-on-amure',
#   'Lat': 53.1406,
#   'Lng': 140.73,
#   'Max Temp': -18.96,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.69,
#   'Country': 'RU',
#   'Date': 1704694360},
#  {'City': 'dudinka',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': -20.77,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Date': 1704694360},
#  {'City': 'paris',
#   'Lat': 48.8534,
#   'Lng': 2.3488,
#   'Max Temp': -0.13,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'FR',
#   'Date': 1704693908},
#  {'City': 'santa cruz',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 23.7,
#   'Humidity': 100,
#   'Cloudiness': 68,
#   'Wind Speed': 5.14,
#   'Country': 'BO',
#   'Date': 1704694362},
#  {'City': 'horta',
#   'Lat': 38.5333,
#   'Lng': -28.6333,
#   'Max Temp': 15.57,
#   'Humidity': 69,
#   'Cloudiness': 86,
#   'Wind Speed': 4.92,
#   'Country': 'PT',
#   'Date': 1704694362},
#  {'City': 'kapuskasing',
#   'Lat': 49.4169,
#   'Lng': -82.4331,
#   'Max Temp': -16.95,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': 1704694363},
#  {'City': 'pucallpa',
#   'Lat': -8.3791,
#   'Lng': -74.5539,
#   'Max Temp': 25.02,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'PE',
#   'Date': 1704694364},
#  {'City': 'hawaiian paradise park',
#   'Lat': 19.5933,
#   'Lng': -154.9731,
#   'Max Temp': 21.73,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694364},
#  {'City': 'vernon',
#   'Lat': 50.2581,
#   'Lng': -119.2691,
#   'Max Temp': -6.83,
#   'Humidity': 90,
#   'Cloudiness': 94,
#   'Wind Speed': 0.65,
#   'Country': 'CA',
#   'Date': 1704694058},
#  {'City': 'reggane',
#   'Lat': 26.7158,
#   'Lng': 0.1714,
#   'Max Temp': 14.42,
#   'Humidity': 31,
#   'Cloudiness': 74,
#   'Wind Speed': 3.08,
#   'Country': 'DZ',
#   'Date': 1704694366},
#  {'City': 'charters towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 32.03,
#   'Humidity': 48,
#   'Cloudiness': 95,
#   'Wind Speed': 4.34,
#   'Country': 'AU',
#   'Date': 1704694366},
#  {'City': 'quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 27.97,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 1.54,
#   'Country': 'MZ',
#   'Date': 1704694367},
#  {'City': 'senges',
#   'Lat': -24.1128,
#   'Lng': -49.4636,
#   'Max Temp': 20.96,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 0.84,
#   'Country': 'BR',
#   'Date': 1704694368},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 16.71,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 7.36,
#   'Country': 'AU',
#   'Date': 1704694368},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 20.47,
#   'Humidity': 74,
#   'Cloudiness': 36,
#   'Wind Speed': 10.6,
#   'Country': 'US',
#   'Date': 1704694369},
#  {'City': 'moree',
#   'Lat': -29.4667,
#   'Lng': 149.85,
#   'Max Temp': 27.22,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'AU',
#   'Date': 1704694370},
#  {'City': 'puerto natales',
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 4.41,
#   'Humidity': 87,
#   'Cloudiness': 67,
#   'Wind Speed': 4.38,
#   'Country': 'CL',
#   'Date': 1704694370},
#  {'City': 'kerikeri',
#   'Lat': -35.2268,
#   'Lng': 173.9474,
#   'Max Temp': 19.83,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 3.34,
#   'Country': 'NZ',
#   'Date': 1704694207},
#  {'City': 'bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 26.01,
#   'Humidity': 48,
#   'Cloudiness': 22,
#   'Wind Speed': 5.77,
#   'Country': 'GW',
#   'Date': 1704694372},
#  {'City': 'nefteyugansk',
#   'Lat': 61.0998,
#   'Lng': 72.6035,
#   'Max Temp': -13.26,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'RU',
#   'Date': 1704694373},
#  {'City': 'rongelap',
#   'Lat': 11.1635,
#   'Lng': 166.8941,
#   'Max Temp': 27.12,
#   'Humidity': 77,
#   'Cloudiness': 63,
#   'Wind Speed': 9.4,
#   'Country': 'MH',
#   'Date': 1704694374},
#  {'City': 'san antonio de pale',
#   'Lat': -1.4014,
#   'Lng': 5.6325,
#   'Max Temp': 27.7,
#   'Humidity': 76,
#   'Cloudiness': 36,
#   'Wind Speed': 5.49,
#   'Country': 'GQ',
#   'Date': 1704694374},
#  {'City': 'graaff-reinet',
#   'Lat': -32.2522,
#   'Lng': 24.5308,
#   'Max Temp': 16.07,
#   'Humidity': 90,
#   'Cloudiness': 96,
#   'Wind Speed': 2.51,
#   'Country': 'ZA',
#   'Date': 1704694375},
#  {'City': 'betio village',
#   'Lat': 1.358,
#   'Lng': 172.9211,
#   'Max Temp': 30.02,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 7.13,
#   'Country': 'KI',
#   'Date': 1704694376},
#  {'City': 'mahibadhoo',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 27.74,
#   'Humidity': 73,
#   'Cloudiness': 89,
#   'Wind Speed': 3.32,
#   'Country': 'MV',
#   'Date': 1704694377},
#  {'City': 'vetovo',
#   'Lat': 43.7,
#   'Lng': 26.2667,
#   'Max Temp': 0.75,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Country': 'BG',
#   'Date': 1704694377},
#  {'City': 'petropavlovsk-kamchatsky',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': -15.68,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': 1704694378},
#  {'City': 'rio grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 22.19,
#   'Humidity': 91,
#   'Cloudiness': 81,
#   'Wind Speed': 3.06,
#   'Country': 'BR',
#   'Date': 1704694379},
#  {'City': 'oasis',
#   'Lat': 33.4659,
#   'Lng': -116.0989,
#   'Max Temp': 11.94,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1704694379},
#  {'City': 'port shepstone',
#   'Lat': -30.7414,
#   'Lng': 30.455,
#   'Max Temp': 22.28,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.24,
#   'Country': 'ZA',
#   'Date': 1704694380},
#  {'City': 'nanao',
#   'Lat': 37.05,
#   'Lng': 136.9667,
#   'Max Temp': 3.11,
#   'Humidity': 69,
#   'Cloudiness': 98,
#   'Wind Speed': 4.07,
#   'Country': 'JP',
#   'Date': 1704694381},
#  {'City': 'san luis',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 20.77,
#   'Humidity': 80,
#   'Cloudiness': 5,
#   'Wind Speed': 3.21,
#   'Country': 'AR',
#   'Date': 1704694382},
#  {'City': 'robstown',
#   'Lat': 27.7903,
#   'Lng': -97.6689,
#   'Max Temp': 20.42,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Country': 'US',
#   'Date': 1704694384},
#  {'City': 'vorgashor',
#   'Lat': 67.5833,
#   'Lng': 63.95,
#   'Max Temp': -24.23,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': 1704694384},
#  {'City': 'nishinoomote',
#   'Lat': 30.7333,
#   'Lng': 131,
#   'Max Temp': 10.31,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 6.17,
#   'Country': 'JP',
#   'Date': 1704694385},
#  {'City': 'phan rang-thap cham',
#   'Lat': 11.5667,
#   'Lng': 108.9833,
#   'Max Temp': 29.07,
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 6.15,
#   'Country': 'VN',
#   'Date': 1704694386},
#  {'City': 'puerto san jose',
#   'Lat': 13.9256,
#   'Lng': -90.8244,
#   'Max Temp': 23.28,
#   'Humidity': 85,
#   'Cloudiness': 21,
#   'Wind Speed': 1.99,
#   'Country': 'GT',
#   'Date': 1704694160},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 28.77,
#   'Humidity': 77,
#   'Cloudiness': 61,
#   'Wind Speed': 3.88,
#   'Country': 'RE',
#   'Date': 1704694387},
#  {'City': 'noyabrsk',
#   'Lat': 63.1994,
#   'Lng': 75.4507,
#   'Max Temp': -19.31,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.81,
#   'Country': 'RU',
#   'Date': 1704694388},
#  {'City': 'matadi',
#   'Lat': -5.8167,
#   'Lng': 13.45,
#   'Max Temp': 24.01,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 0.81,
#   'Country': 'CD',
#   'Date': 1704694389},
#  {'City': 'haiku-pauwela',
#   'Lat': 20.9219,
#   'Lng': -156.3051,
#   'Max Temp': 23.47,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1704694390},
#  {'City': 'rawlins',
#   'Lat': 41.7911,
#   'Lng': -107.2387,
#   'Max Temp': -5.06,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1704694390},
#  {'City': 'asuncion nochixtlan',
#   'Lat': 17.4667,
#   'Lng': -97.2333,
#   'Max Temp': 10.56,
#   'Humidity': 94,
#   'Cloudiness': 27,
#   'Wind Speed': 0.3,
#   'Country': 'MX',
#   'Date': 1704694391},
#  {'City': 'ilhabela',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 23.41,
#   'Humidity': 90,
#   'Cloudiness': 12,
#   'Wind Speed': 2.56,
#   'Country': 'BR',
#   'Date': 1704694392},
#  {'City': 'bairnsdale',
#   'Lat': -37.8333,
#   'Lng': 147.6167,
#   'Max Temp': 19.47,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'AU',
#   'Date': 1704694392},
#  {'City': 'qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 0.58,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 3.71,
#   'Country': 'GL',
#   'Date': 1704694393},
#  {'City': 'pontiac',
#   'Lat': 42.6389,
#   'Lng': -83.2911,
#   'Max Temp': 1.75,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1704694394},
#  {'City': 'ilebo',
#   'Lat': -4.3167,
#   'Lng': 20.5833,
#   'Max Temp': 22.91,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 0.18,
#   'Country': 'CD',
#   'Date': 1704694396},
#  {'City': 'tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 29.08,
#   'Humidity': 72,
#   'Cloudiness': 70,
#   'Wind Speed': 5.04,
#   'Country': 'ID',
#   'Date': 1704694396},
#  {'City': 'enewetak',
#   'Lat': 11.3474,
#   'Lng': 162.3373,
#   'Max Temp': 27.19,
#   'Humidity': 72,
#   'Cloudiness': 30,
#   'Wind Speed': 9.52,
#   'Country': 'MH',
#   'Date': 1704694398},
#  {'City': 'morant bay',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 25.79,
#   'Humidity': 84,
#   'Cloudiness': 9,
#   'Wind Speed': 4.5,
#   'Country': 'JM',
#   'Date': 1704694398},
#  {'City': 'friedland',
#   'Lat': 51.4167,
#   'Lng': 9.9333,
#   'Max Temp': -4.36,
#   'Humidity': 69,
#   'Cloudiness': 98,
#   'Wind Speed': 2.68,
#   'Country': 'DE',
#   'Date': 1704694399},
#  {'City': 'adam',
#   'Lat': 22.3756,
#   'Lng': 57.5233,
#   'Max Temp': 22.67,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 3.7,
#   'Country': 'OM',
#   'Date': 1704694400},
#  {'City': 'castillos',
#   'Lat': -34.1667,
#   'Lng': -53.8333,
#   'Max Temp': 19.37,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.2,
#   'Country': 'UY',
#   'Date': 1704694400},
#  {'City': 'san luis de la loma',
#   'Lat': 17.2706,
#   'Lng': -100.8939,
#   'Max Temp': 23.89,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.03,
#   'Country': 'MX',
#   'Date': 1704694401},
#  {'City': 'nova sintra',
#   'Lat': 14.8667,
#   'Lng': -24.7167,
#   'Max Temp': 21.66,
#   'Humidity': 66,
#   'Cloudiness': 94,
#   'Wind Speed': 6.53,
#   'Country': 'CV',
#   'Date': 1704694402},
#  {'City': 'nchelenge',
#   'Lat': -9.3451,
#   'Lng': 28.734,
#   'Max Temp': 20.45,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.54,
#   'Country': 'ZM',
#   'Date': 1704694402},
#  {'City': 'korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': -0.86,
#   'Humidity': 53,
#   'Cloudiness': 2,
#   'Wind Speed': 0.23,
#   'Country': 'CN',
#   'Date': 1704694403},
#  {'City': 'mazatlan',
#   'Lat': 23.2167,
#   'Lng': -106.4167,
#   'Max Temp': 20.51,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 0.45,
#   'Country': 'MX',
#   'Date': 1704694404},
#  {'City': 'banda aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 29.7,
#   'Humidity': 72,
#   'Cloudiness': 34,
#   'Wind Speed': 6.52,
#   'Country': 'ID',
#   'Date': 1704694404},
#  {'City': 'gebeit',
#   'Lat': 21.0667,
#   'Lng': 36.3167,
#   'Max Temp': 20.82,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.05,
#   'Country': 'SD',
#   'Date': 1704694405},
#  {'City': 'saint-louis',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 20.29,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 3.15,
#   'Country': 'SN',
#   'Date': 1704694406},
#  {'City': "st. john's",
#   'Lat': 47.5649,
#   'Lng': -52.7093,
#   'Max Temp': -5.02,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Country': 'CA',
#   'Date': 1704694346},
#  {'City': 'recani',
#   'Lat': 31.2846,
#   'Lng': -4.2688,
#   'Max Temp': 7.59,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 0.88,
#   'Country': 'MA',
#   'Date': 1704694407},
#  {'City': 'aginskoye',
#   'Lat': 51.1,
#   'Lng': 114.53,
#   'Max Temp': -11.64,
#   'Humidity': 76,
#   'Cloudiness': 7,
#   'Wind Speed': 7.83,
#   'Country': 'RU',
#   'Date': 1704694311},
#  {'City': 'aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -31.43,
#   'Humidity': 100,
#   'Cloudiness': 96,
#   'Wind Speed': 2.86,
#   'Country': 'RU',
#   'Date': 1704694408},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -8.85,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694293},
#  {'City': "novhorod-sivers'kyy",
#   'Lat': 52.0058,
#   'Lng': 33.2615,
#   'Max Temp': -16.45,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Country': 'UA',
#   'Date': 1704694410},
#  {'City': 'abuyog',
#   'Lat': 10.6667,
#   'Lng': 125.05,
#   'Max Temp': 27.93,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 4.48,
#   'Country': 'PH',
#   'Date': 1704694410},
#  {'City': 'suizhou',
#   'Lat': 31.7111,
#   'Lng': 113.3631,
#   'Max Temp': 11.69,
#   'Humidity': 55,
#   'Cloudiness': 47,
#   'Wind Speed': 1.76,
#   'Country': 'CN',
#   'Date': 1704694411},
#  {'City': 'tolanaro',
#   'Lat': -25.0319,
#   'Lng': 46.9987,
#   'Max Temp': 27.12,
#   'Humidity': 79,
#   'Cloudiness': 44,
#   'Wind Speed': 6.53,
#   'Country': 'MG',
#   'Date': 1704694412},
#  {'City': 'timbuktu',
#   'Lat': 16.7735,
#   'Lng': -3.0074,
#   'Max Temp': 19.98,
#   'Humidity': 15,
#   'Cloudiness': 58,
#   'Wind Speed': 4.6,
#   'Country': 'ML',
#   'Date': 1704694412},
#  {'City': 'bridgewater',
#   'Lat': 44.3835,
#   'Lng': -64.5155,
#   'Max Temp': -4.18,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'CA',
#   'Date': 1704694413},
#  {'City': 'puerto aysen',
#   'Lat': -45.4,
#   'Lng': -72.7,
#   'Max Temp': 6.77,
#   'Humidity': 99,
#   'Cloudiness': 82,
#   'Wind Speed': 1.96,
#   'Country': 'CL',
#   'Date': 1704694414},
#  {'City': 'utrik',
#   'Lat': 11.2278,
#   'Lng': 169.8474,
#   'Max Temp': 27,
#   'Humidity': 68,
#   'Cloudiness': 33,
#   'Wind Speed': 8.45,
#   'Country': 'MH',
#   'Date': 1704694415},
#  {'City': 'kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 27.68,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 3.78,
#   'Country': 'LK',
#   'Date': 1704694163},
#  {'City': 'fale old settlement',
#   'Lat': -9.3852,
#   'Lng': -171.2468,
#   'Max Temp': 29.02,
#   'Humidity': 65,
#   'Cloudiness': 53,
#   'Wind Speed': 1.5,
#   'Country': 'TK',
#   'Date': 1704694416},
#  {'City': 'chagoda',
#   'Lat': 59.164,
#   'Lng': 35.3285,
#   'Max Temp': -15.22,
#   'Humidity': 83,
#   'Cloudiness': 22,
#   'Wind Speed': 4.34,
#   'Country': 'RU',
#   'Date': 1704694418},
#  {'City': 'tsiombe',
#   'Lat': -25.3,
#   'Lng': 45.4833,
#   'Max Temp': 29.85,
#   'Humidity': 63,
#   'Cloudiness': 10,
#   'Wind Speed': 3.38,
#   'Country': 'MG',
#   'Date': 1704694418},
#  {'City': 'azadshahr',
#   'Lat': 34.7909,
#   'Lng': 48.5707,
#   'Max Temp': 8.16,
#   'Humidity': 17,
#   'Cloudiness': 14,
#   'Wind Speed': 2.46,
#   'Country': 'IR',
#   'Date': 1704694159},
#  {'City': 'sinjar',
#   'Lat': 36.3209,
#   'Lng': 41.8754,
#   'Max Temp': 10.06,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 2.49,
#   'Country': 'IQ',
#   'Date': 1704694420},
#  {'City': 'nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': -0.83,
#   'Humidity': 69,
#   'Cloudiness': 55,
#   'Wind Speed': 7.49,
#   'Country': 'JP',
#   'Date': 1704694420},
#  {'City': 'belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 25.12,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 2.19,
#   'Country': 'BR',
#   'Date': 1704694421},
#  {'City': 'villamontes',
#   'Lat': -21.25,
#   'Lng': -63.5,
#   'Max Temp': 23.79,
#   'Humidity': 80,
#   'Cloudiness': 61,
#   'Wind Speed': 1.66,
#   'Country': 'BO',
#   'Date': 1704694422},
#  {'City': 'kralendijk',
#   'Lat': 12.15,
#   'Lng': -68.2667,
#   'Max Temp': 26.99,
#   'Humidity': 78,
#   'Cloudiness': 79,
#   'Wind Speed': 8.23,
#   'Country': 'BQ',
#   'Date': 1704694227},
#  {'City': 'kalisz',
#   'Lat': 51.7611,
#   'Lng': 18.091,
#   'Max Temp': -8.79,
#   'Humidity': 69,
#   'Cloudiness': 95,
#   'Wind Speed': 5.86,
#   'Country': 'PL',
#   'Date': 1704694423},
#  {'City': 'cukai',
#   'Lat': 4.25,
#   'Lng': 103.4167,
#   'Max Temp': 29.97,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 4.69,
#   'Country': 'MY',
#   'Date': 1704694424},
#  {'City': 'sarandi del yi',
#   'Lat': -33.35,
#   'Lng': -55.6333,
#   'Max Temp': 18.85,
#   'Humidity': 95,
#   'Cloudiness': 57,
#   'Wind Speed': 2.58,
#   'Country': 'UY',
#   'Date': 1704694424},
#  {'City': 'dieppe',
#   'Lat': 49.75,
#   'Lng': 1.1667,
#   'Max Temp': -1.9,
#   'Humidity': 82,
#   'Cloudiness': 5,
#   'Wind Speed': 0.89,
#   'Country': 'FR',
#   'Date': 1704694318},
#  {'City': 'sirte',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 11.87,
#   'Humidity': 49,
#   'Cloudiness': 81,
#   'Wind Speed': 7.03,
#   'Country': 'LY',
#   'Date': 1704694427},
#  {'City': 'manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 28.58,
#   'Humidity': 72,
#   'Cloudiness': 79,
#   'Wind Speed': 3,
#   'Country': 'ID',
#   'Date': 1704694428},
#  {'City': 'kasungu',
#   'Lat': -13.0333,
#   'Lng': 33.4833,
#   'Max Temp': 19.78,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.29,
#   'Country': 'MW',
#   'Date': 1704694428},
#  {'City': 'vizinga',
#   'Lat': 61.0749,
#   'Lng': 50.1031,
#   'Max Temp': -18.62,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 2.66,
#   'Country': 'RU',
#   'Date': 1704694429},
#  {'City': 'manismata',
#   'Lat': -2.4667,
#   'Lng': 111.0333,
#   'Max Temp': 29.39,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 2.1,
#   'Country': 'ID',
#   'Date': 1704694430},
#  {'City': 'kisangani',
#   'Lat': 0.5167,
#   'Lng': 25.2,
#   'Max Temp': 24.52,
#   'Humidity': 67,
#   'Cloudiness': 42,
#   'Wind Speed': 0.37,
#   'Country': 'CD',
#   'Date': 1704694246},
#  {'City': 'batangafo',
#   'Lat': 7.3008,
#   'Lng': 18.2833,
#   'Max Temp': 20.65,
#   'Humidity': 21,
#   'Cloudiness': 91,
#   'Wind Speed': 1.17,
#   'Country': 'CF',
#   'Date': 1704694431},
#  {'City': 'plouzane',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 4.03,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'FR',
#   'Date': 1704694432},
#  {'City': 'aripuana',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp': 22.6,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.26,
#   'Country': 'BR',
#   'Date': 1704694194},
#  {'City': 'vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': -32.78,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1704694433},
#  {'City': 'queenstown',
#   'Lat': -31.8976,
#   'Lng': 26.8753,
#   'Max Temp': 17.27,
#   'Humidity': 71,
#   'Cloudiness': 95,
#   'Wind Speed': 2.34,
#   'Country': 'ZA',
#   'Date': 1704694434},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
# ...
#  {'City': 'petrila',
#   'Lat': 45.45,
#   'Lng': 23.4167,
#   'Max Temp': 3.31,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.13,
#   'Country': 'RO',
#   'Date': 1704694603},
#  {'City': 'bornu yassu',
#   'Lat': 12.2774,
#   'Lng': 12.5552,
#   'Max Temp': 15.72,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 3.1,
#   'Country': 'NG',
#   'Date': 1704694604},
#  {'City': 'gereida',
#   'Lat': 11.2811,
#   'Lng': 25.1414,
#   'Max Temp': 17.12,
#   'Humidity': 31,
#   'Cloudiness': 64,
#   'Wind Speed': 4.4,
#   'Country': 'SD',
#   'Date': 1704694604},
#  {'City': 'quellon',
#   'Lat': -43.1167,
#   'Lng': -73.6167,
#   'Max Temp': 8.8,
#   'Humidity': 79,
#   'Cloudiness': 13,
#   'Wind Speed': 2.09,
#   'Country': 'CL',
#   'Date': 1704694605},
#  {'City': 'taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 18.37,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 3.7,
#   'Country': 'ML',
#   'Date': 1704694606},
#  {'City': 'morehead city',
#   'Lat': 34.7229,
#   'Lng': -76.726,
#   'Max Temp': 7.77,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1704694444},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 24.97,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': 1704694352},
#  {'City': 'lengshuitan',
#   'Lat': 26.4111,
#   'Lng': 111.5956,
#   'Max Temp': 9.93,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.47,
#   'Country': 'CN',
#   'Date': 1704694608},
#  {'City': 'santiago',
#   'Lat': -33.4569,
#   'Lng': -70.6483,
#   'Max Temp': 20.75,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'CL',
#   'Date': 1704693966},
#  {'City': 'wynyard',
#   'Lat': -41,
#   'Lng': 145.7167,
#   'Max Temp': 19.68,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 2.54,
#   'Country': 'AU',
#   'Date': 1704694610},
#  {'City': 'myeik',
#   'Lat': 12.4333,
#   'Lng': 98.6,
#   'Max Temp': 30.76,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'MM',
#   'Date': 1704694610},
#  {'City': 'guider',
#   'Lat': 9.9342,
#   'Lng': 13.9486,
#   'Max Temp': 20.74,
#   'Humidity': 20,
#   'Cloudiness': 55,
#   'Wind Speed': 1.27,
#   'Country': 'CM',
#   'Date': 1704694611},
#  {'City': 'merizo village',
#   'Lat': 13.2658,
#   'Lng': 144.6691,
#   'Max Temp': 29.43,
#   'Humidity': 84,
#   'Cloudiness': 70,
#   'Wind Speed': 7.17,
#   'Country': 'GU',
#   'Date': 1704694612},
#  {'City': 'curico',
#   'Lat': -34.9833,
#   'Lng': -71.2333,
#   'Max Temp': 17.06,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'CL',
#   'Date': 1704694613},
#  {'City': 'vilhena',
#   'Lat': -12.7406,
#   'Lng': -60.1458,
#   'Max Temp': 20.78,
#   'Humidity': 98,
#   'Cloudiness': 92,
#   'Wind Speed': 1.27,
#   'Country': 'BR',
#   'Date': 1704694613},
#  {'City': 'bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 25.88,
#   'Humidity': 55,
#   'Cloudiness': 2,
#   'Wind Speed': 10.38,
#   'Country': 'SO',
#   'Date': 1704694614},
#  {'City': "bol'sherech'ye",
#   'Lat': 56.0925,
#   'Lng': 74.6272,
#   'Max Temp': -3.16,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.5,
#   'Country': 'RU',
#   'Date': 1704694615},
#  {'City': 'tralee',
#   'Lat': 52.2704,
#   'Lng': -9.7026,
#   'Max Temp': 1.14,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Country': 'IE',
#   'Date': 1704694615},
#  {'City': 'alesund',
#   'Lat': 62.4723,
#   'Lng': 6.1549,
#   'Max Temp': 3.08,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'NO',
#   'Date': 1704694459},
#  {'City': 'kailua-kona',
#   'Lat': 19.6406,
#   'Lng': -155.9956,
#   'Max Temp': 24.98,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1704694328},
#  {'City': 'ontario',
#   'Lat': 34.0633,
#   'Lng': -117.6509,
#   'Max Temp': 9.12,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1704694618},
#  {'City': "port saint john's",
#   'Lat': -31.6229,
#   'Lng': 29.5448,
#   'Max Temp': 20.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.21,
#   'Country': 'ZA',
#   'Date': 1704694619},
#  {'City': 'grand-bourg',
#   'Lat': 15.8835,
#   'Lng': -61.3148,
#   'Max Temp': 22.97,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 8.44,
#   'Country': 'GP',
#   'Date': 1704694619},
#  {'City': 'urengoy',
#   'Lat': 65.9667,
#   'Lng': 78.3667,
#   'Max Temp': -20.82,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.69,
#   'Country': 'RU',
#   'Date': 1704694620},
#  {'City': 'igarka',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': -26.1,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 5.5,
#   'Country': 'RU',
#   'Date': 1704694621},
#  {'City': 'faya-largeau',
#   'Lat': 17.9257,
#   'Lng': 19.1043,
#   'Max Temp': 17.02,
#   'Humidity': 15,
#   'Cloudiness': 11,
#   'Wind Speed': 5.67,
#   'Country': 'TD',
#   'Date': 1704694622},
#  {'City': 'yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 29.88,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Country': 'AU',
#   'Date': 1704694623},
#  {'City': 'przasnysz',
#   'Lat': 53.0191,
#   'Lng': 20.8803,
#   'Max Temp': -12.01,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6,
#   'Country': 'PL',
#   'Date': 1704694624},
#  {'City': 'maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 24.2,
#   'Humidity': 88,
#   'Cloudiness': 5,
#   'Wind Speed': 2.86,
#   'Country': 'BR',
#   'Date': 1704694624},
#  {'City': 'egilsstadir',
#   'Lat': 65.2653,
#   'Lng': -14.3948,
#   'Max Temp': 4.65,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 6.41,
#   'Country': 'IS',
#   'Date': 1704694625},
#  {'City': 'laojunmiao',
#   'Lat': 39.8333,
#   'Lng': 97.7333,
#   'Max Temp': 0.63,
#   'Humidity': 21,
#   'Cloudiness': 55,
#   'Wind Speed': 4.73,
#   'Country': 'CN',
#   'Date': 1704694626},
#  {'City': 'rawatbhata',
#   'Lat': 24.9333,
#   'Lng': 75.5833,
#   'Max Temp': 19.87,
#   'Humidity': 60,
#   'Cloudiness': 76,
#   'Wind Speed': 2.11,
#   'Country': 'IN',
#   'Date': 1704694626},
#  {'City': 'markivka',
#   'Lat': 49.5229,
#   'Lng': 39.5705,
#   'Max Temp': -10.94,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 7.24,
#   'Country': 'UA',
#   'Date': 1704694627},
#  {'City': 'nandigama',
#   'Lat': 16.7833,
#   'Lng': 80.3,
#   'Max Temp': 27.8,
#   'Humidity': 40,
#   'Cloudiness': 14,
#   'Wind Speed': 4.76,
#   'Country': 'IN',
#   'Date': 1704694628},
#  {'City': 'labytnangi',
#   'Lat': 66.6572,
#   'Lng': 66.4183,
#   'Max Temp': -23.88,
#   'Humidity': 97,
#   'Cloudiness': 68,
#   'Wind Speed': 1.31,
#   'Country': 'RU',
#   'Date': 1704694629},
#  {'City': 'kasongo-lunda',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 21.56,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0.66,
#   'Country': 'CD',
#   'Date': 1704694629},
#  {'City': 'lichuan',
#   'Lat': 30.3,
#   'Lng': 108.85,
#   'Max Temp': 9.75,
#   'Humidity': 68,
#   'Cloudiness': 52,
#   'Wind Speed': 1.15,
#   'Country': 'CN',
#   'Date': 1704694630},
#  {'City': 'nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 16.99,
#   'Humidity': 63,
#   'Cloudiness': 7,
#   'Wind Speed': 3.6,
#   'Country': 'MR',
#   'Date': 1704694631},
#  {'City': 'mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 26.71,
#   'Humidity': 61,
#   'Cloudiness': 93,
#   'Wind Speed': 6.41,
#   'Country': 'AU',
#   'Date': 1704694596},
#  {'City': 'manado',
#   'Lat': 1.487,
#   'Lng': 124.8455,
#   'Max Temp': 33.43,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'ID',
#   'Date': 1704694633},
#  {'City': 'socorro',
#   'Lat': 31.6546,
#   'Lng': -106.3033,
#   'Max Temp': 3.92,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 11.83,
#   'Country': 'US',
#   'Date': 1704694389},
#  {'City': 'coahuayana de hidalgo',
#   'Lat': 18.7,
#   'Lng': -103.6583,
#   'Max Temp': 21.21,
#   'Humidity': 91,
#   'Cloudiness': 85,
#   'Wind Speed': 1.52,
#   'Country': 'MX',
#   'Date': 1704694634},
#  {'City': 'lincoln',
#   'Lat': 40.8,
#   'Lng': -96.667,
#   'Max Temp': 1.21,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'US',
#   'Date': 1704694635},
#  {'City': 'corbie',
#   'Lat': 49.9067,
#   'Lng': 2.5068,
#   'Max Temp': -1.51,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Country': 'FR',
#   'Date': 1704694636},
#  {'City': 'talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 23.84,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.62,
#   'Country': 'PE',
#   'Date': 1704694636},
#  {'City': 'kosti',
#   'Lat': 13.1629,
#   'Lng': 32.6635,
#   'Max Temp': 23.87,
#   'Humidity': 26,
#   'Cloudiness': 12,
#   'Wind Speed': 3.26,
#   'Country': 'SD',
#   'Date': 1704694637},
#  {'City': 'banjarmasin',
#   'Lat': -3.3244,
#   'Lng': 114.591,
#   'Max Temp': 28.08,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Country': 'ID',
#   'Date': 1704694638},
#  {'City': 'smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': -6.82,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Date': 1704694638},
#  {'City': 'konakovo',
#   'Lat': 56.7,
#   'Lng': 36.7667,
#   'Max Temp': -20.49,
#   'Humidity': 86,
#   'Cloudiness': 36,
#   'Wind Speed': 2.4,
#   'Country': 'RU',
#   'Date': 1704694639},
#  {'City': 'sao vicente',
#   'Lat': -23.9631,
#   'Lng': -46.3919,
#   'Max Temp': 28.1,
#   'Humidity': 26,
#   'Cloudiness': 7,
#   'Wind Speed': 0.77,
#   'Country': 'BR',
#   'Date': 1704694640},
#  {'City': 'fisterra',
#   'Lat': 42.9049,
#   'Lng': -9.2629,
#   'Max Temp': 2.08,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'ES',
#   'Date': 1704694640},
#  {'City': 'inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 27.8,
#   'Humidity': 62,
#   'Cloudiness': 18,
#   'Wind Speed': 1.18,
#   'Country': 'MZ',
#   'Date': 1704694641},
#  {'City': 'bondo',
#   'Lat': 3.8146,
#   'Lng': 23.6866,
#   'Max Temp': 21.43,
#   'Humidity': 37,
#   'Cloudiness': 45,
#   'Wind Speed': 1.69,
#   'Country': 'CD',
#   'Date': 1704694642},
#  {'City': 'sandnessjoen',
#   'Lat': 66.0217,
#   'Lng': 12.6316,
#   'Max Temp': 3.06,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'NO',
#   'Date': 1704694643},
#  {'City': 'alaghsas',
#   'Lat': 17.0187,
#   'Lng': 8.0168,
#   'Max Temp': 14.94,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'NE',
#   'Date': 1704694369},
#  {'City': 'mulayjah',
#   'Lat': 27.271,
#   'Lng': 48.4242,
#   'Max Temp': 13.54,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 2.75,
#   'Country': 'SA',
#   'Date': 1704694644},
#  {'City': 'peniche',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 7.38,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 3.05,
#   'Country': 'PT',
#   'Date': 1704694645},
#  {'City': 'vadso',
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': -4.51,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 7.72,
#   'Country': 'NO',
#   'Date': 1704694645},
#  {'City': 'abu jibeha',
#   'Lat': 11.4562,
#   'Lng': 31.2285,
#   'Max Temp': 23.04,
#   'Humidity': 25,
#   'Cloudiness': 22,
#   'Wind Speed': 2.1,
#   'Country': 'SD',
#   'Date': 1704694646},
#  {'City': 'padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 31.03,
#   'Humidity': 79,
#   'Cloudiness': 88,
#   'Wind Speed': 1.85,
#   'Country': 'ID',
#   'Date': 1704694647},
#  {'City': 'ta`u',
#   'Lat': -14.2336,
#   'Lng': -169.5144,
#   'Max Temp': 28.67,
#   'Humidity': 73,
#   'Cloudiness': 71,
#   'Wind Speed': 1.51,
#   'Country': 'AS',
#   'Date': 1704694649},
#  {'City': 'kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 21.01,
#   'Humidity': 15,
#   'Cloudiness': 99,
#   'Wind Speed': 3.7,
#   'Country': 'ML',
#   'Date': 1704694649},
#  {'City': 'santiago de cao',
#   'Lat': -7.9589,
#   'Lng': -79.2392,
#   'Max Temp': 21.07,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'PE',
#   'Date': 1704694650},
#  {'City': 'forest grove',
#   'Lat': 45.5198,
#   'Lng': -123.1107,
#   'Max Temp': 5.93,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1704694651},
#  {'City': 'primero de mayo',
#   'Lat': -32.2552,
#   'Lng': -58.4228,
#   'Max Temp': 21.42,
#   'Humidity': 96,
#   'Cloudiness': 34,
#   'Wind Speed': 2.72,
#   'Country': 'AR',
#   'Date': 1704694651},
#  {'City': 'kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 28.64,
#   'Humidity': 80,
#   'Cloudiness': 44,
#   'Wind Speed': 2.64,
#   'Country': 'SB',
#   'Date': 1704694652},
#  {'City': 'abu zabad',
#   'Lat': 12.35,
#   'Lng': 29.25,
#   'Max Temp': 19.09,
#   'Humidity': 32,
#   'Cloudiness': 36,
#   'Wind Speed': 5.58,
#   'Country': 'SD',
#   'Date': 1704694653},
#  {'City': 'fort st. john',
#   'Lat': 56.2499,
#   'Lng': -120.8529,
#   'Max Temp': -22.06,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': 1704694654},
#  {'City': 'mexico',
#   'Lat': 15.0646,
#   'Lng': 120.7198,
#   'Max Temp': 30.64,
#   'Humidity': 58,
#   'Cloudiness': 86,
#   'Wind Speed': 6.29,
#   'Country': 'PH',
#   'Date': 1704694114},
#  {'City': 'onguday',
#   'Lat': 50.75,
#   'Lng': 86.15,
#   'Max Temp': -4.26,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 2.33,
#   'Country': 'RU',
#   'Date': 1704694655},
#  {'City': 'sanawad',
#   'Lat': 22.1833,
#   'Lng': 76.0667,
#   'Max Temp': 27.5,
#   'Humidity': 40,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'IN',
#   'Date': 1704694656},
#  {'City': 'caister-on-sea',
#   'Lat': 52.6481,
#   'Lng': 1.7265,
#   'Max Temp': 3.88,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 9.19,
#   'Country': 'GB',
#   'Date': 1704694656},
#  {'City': 'colonia',
#   'Lat': 50.9333,
#   'Lng': 6.95,
#   'Max Temp': -0.64,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'DE',
#   'Date': 1704694443},
#  {'City': 'shizuoka',
#   'Lat': 34.9769,
#   'Lng': 138.3831,
#   'Max Temp': 8.61,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 1.17,
#   'Country': 'JP',
#   'Date': 1704694409},
#  {'City': 'bonito',
#   'Lat': -21.1211,
#   'Lng': -56.4819,
#   'Max Temp': 25.14,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 2.1,
#   'Country': 'BR',
#   'Date': 1704694658},
#  {'City': 'tudor vladimirescu',
#   'Lat': 45.5667,
#   'Lng': 27.65,
#   'Max Temp': -3.43,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.19,
#   'Country': 'RO',
#   'Date': 1704694659},
#  {'City': 'ourem',
#   'Lat': 39.6417,
#   'Lng': -8.5919,
#   'Max Temp': 4.7,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 1.39,
#   'Country': 'PT',
#   'Date': 1704694660},
#  {'City': 'burang',
#   'Lat': 30.25,
#   'Lng': 81.1667,
#   'Max Temp': -1.69,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 2.04,
#   'Country': 'CN',
#   'Date': 1704694528},
#  {'City': "nikol'sk",
#   'Lat': 53.7189,
#   'Lng': 46.0712,
#   'Max Temp': -24.83,
#   'Humidity': 100,
#   'Cloudiness': 48,
#   'Wind Speed': 2.2,
#   'Country': 'RU',
#   'Date': 1704694661},
#  {'City': 'elko',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': -10.43,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1704694662},
#  {'City': 'amarpatan',
#   'Lat': 24.3167,
#   'Lng': 80.9833,
#   'Max Temp': 21.28,
#   'Humidity': 62,
#   'Cloudiness': 35,
#   'Wind Speed': 2.05,
#   'Country': 'IN',
#   'Date': 1704694662},
#  {'City': 'valley city',
#   'Lat': 46.9233,
#   'Lng': -98.0032,
#   'Max Temp': -16.71,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1704694663},
#  {'City': 'stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 4.98,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'GB',
#   'Date': 1704694664},
#  {'City': 'khunti',
#   'Lat': 23.0833,
#   'Lng': 85.2833,
#   'Max Temp': 18.06,
#   'Humidity': 43,
#   'Cloudiness': 6,
#   'Wind Speed': 2.36,
#   'Country': 'IN',
#   'Date': 1704694664},
#  {'City': 'xilin hot',
#   'Lat': 43.9667,
#   'Lng': 116.0333,
#   'Max Temp': -10.01,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 1.81,
#   'Country': 'CN',
#   'Date': 1704694665},
#  {'City': 'bella union',
#   'Lat': -30.2752,
#   'Lng': -57.6007,
#   'Max Temp': 20.98,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 2.5,
#   'Country': 'UY',
#   'Date': 1704694666},
#  {'City': 'posse',
#   'Lat': -14.0931,
#   'Lng': -46.3694,
#   'Max Temp': 20.04,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'BR',
#   'Date': 1704694666},
#  {'City': 'cuatro cienegas de carranza',
#   'Lat': 26.9833,
#   'Lng': -102.0833,
#   'Max Temp': 11.57,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 1.46,
#   'Country': 'MX',
#   'Date': 1704694667}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  adamstown -25.0660 -130.1015     23.50        76         100        6.14
# 1  grytviken -54.2811  -36.5092      3.88        88          50        1.53
# 2  guarapari -20.6667  -40.4975     24.94        88          47        2.27
# 3   ust-nera  64.5667  143.2000    -43.84        98          81        1.55
# 4       puri  19.8000   85.8500     23.29        45          13        4.07
#
#   Country        Date
# 0      PN  1704694236
# 1      GS  1704694238
# 2      BR  1704694239
# 3      RU  1704694239
# 4      IN  1704694240

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        adamstown -25.0660 -130.1015     23.50        76         100
# 1        grytviken -54.2811  -36.5092      3.88        88          50
# 2        guarapari -20.6667  -40.4975     24.94        88          47
# 3         ust-nera  64.5667  143.2000    -43.84        98          81
# 4             puri  19.8000   85.8500     23.29        45          13
#
#          Wind Speed Country        Date
# City_ID
# 0              6.14      PN  1704694236
# 1              1.53      GS  1704694238
# 2              2.27      BR  1704694239
# 3              1.55      RU  1704694239
# 4              4.07      IN  1704694240

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker='o', facecolors='b', edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker='o', facecolors='b', edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker='o', facecolors='b', edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    print(f"The r-value is: {rvalue**2}")
    
    plt.scatter(x_values, y_values)
    plt.xlabel('Latitude')
    plt.ylabel(title)
    
    plt.plot(x_values, regress_values,"r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15,color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                 ust-nera  64.5667  143.2000    -43.84        98          81
# 4                     puri  19.8000   85.8500     23.29        45          13
# 8        wailua homesteads  22.0669 -159.3780     23.44        87         100
# 9                  klyuchi  52.2667   79.1667      1.52        99         100
# 10                 aasiaat  68.7098  -52.8699    -10.64        83         100
#
#          Wind Speed Country        Date
# City_ID
# 3              1.55      RU  1704694239
# 4              4.07      IN  1704694240
# 8              5.66      US  1704694243
# 9              8.72      RU  1704694243
# 10             5.13      GL  1704694244

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        adamstown -25.0660 -130.1015     23.50        76         100
# 1        grytviken -54.2811  -36.5092      3.88        88          50
# 2        guarapari -20.6667  -40.4975     24.94        88          47
# 5           uturoa -16.7333 -151.4333     27.00        79          64
# 6         waitangi -43.9535 -176.5597     15.46        73          10
#
#          Wind Speed Country        Date
# City_ID
# 0              6.14      PN  1704694236
# 1              1.53      GS  1704694238
# 2              2.27      BR  1704694239
# 5              3.70      PF  1704694241
# 6              0.89      NZ  1704694241

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
title = 'Max Temp (C)'
text_coordinates = (5,-30)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.7945314598053784

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
title = 'Max Temp (C)'
text_coordinates = (-35,7)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.412154610708935

# %% [markdown]
# **Discussion about the linear relationship:** This model is showing the relationship between the maximum temperature as it goes further away from the equator. It is evident that in the northern hemisphere, there is a strong relationship that as you go further north the maximum temperature decreases. Comparitively, in the southern hemisphere it shows that the temperature continues to increase, however not at the rate shown north of the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
title = 'Humidity'
text_coordinates = (45,45)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.18506176460937468

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
title = 'Humidity'
text_coordinates = (-25,30)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.01106578370133352

# %% [markdown]
# **Discussion about the linear relationship:** The regression plots shows a largely inconclusive relationship between a city's latitude and corresponding humidity. The southern hemisphere plot is skewed with a handful of cities with very little humidity, otherwise humidity stays high despite the latitude. The northern hemisphere humidy is very scattered close to the equator, however, as it goes further North the humidity condenses and remains high. One possible conclusion is that due to the winter conditions North, we know that there is a lot of moisture at ground level, i.e. snow, this would contribute to the humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
title = 'Cloudiness'
text_coordinates = (50,60)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.12082335388022983

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
title = 'Cloudiness'
text_coordinates = (-25,50)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 0.0418659445686715

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression model between a city's latiude and cloudiness is slightly positive, showing as the Latitude increases as does the cloudiness. The r-value for each plot is very close to 0, meaning that this relationship is weak and more investigation is required for an accurate use for this data to be utilised.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
title = 'Wind Speed'
text_coordinates = (20,15)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 5.384858230317217e-05

# %%
# Southern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
title = 'Wind Speed'
text_coordinates = (30,20)

plot_linear_regression(x_values, y_values, title, text_coordinates)
# Out:
# The r-value is: 5.384858230317217e-05

# %% [markdown]
# **Discussion about the linear relationship:** The linear relationship between latitude and wind speed is inconclusive. As seen in the scatter plot, the wind speed does not vary as the latitude changes. The regression line slope is horizontal, and so indicates that there is little to no relationship, and so other factors shall be investigated as to determine what impacts a city's wind speed.
